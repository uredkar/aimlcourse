# %% [markdown]
# # Flight Price Prediction Case Study
#
# ## Context and Problem
#  - The objective of this project is to predict the price of a flight with a set of relevant flight details provided
#  - The flight details have information related to flight timings, source and destination details, route details, stops in between, etc.
#  - The dataset consists of about one year of information about various flights and their respective prices.
#
# ## Data Information
#
# The data at hand has eleven features about the spending on advertising and the target variable is the net sales. Attributes are:
#
# - Airline - Company that provides air transport services for traveling passengers. (Independent Variable)
# - Source  - From where the flight is takes off.(Independent Variable)
# - Destination - To where the flight is going.(Independent Variable)
# - Route   - What is the route of each flight.(Independent Variable)
# - Dep Time - Departure Time of the flight.(Independent Variable)
# - Arrival Time - Arrival Time of the flight.(Independent Variable)
# - Duration - Total duration of the flight.(Independent Variable)
# - Total Stops - Number of stops between source and destination.(Independent Variable)
# - Additional info - Additional information about the flight is given.(Independent Variable)
# - Price - Price of each flight.(Dependent Variable)

# %% [markdown]
# **Mounting the Drive**

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# **Loading the required libraries**

# %%
# Libraries to help with reading and manipulating data
import numpy as np
import pandas as pd

# libaries to help with data visualization
import matplotlib.pyplot as pyplot
import matplotlib.pyplot as plt
import seaborn as sns

# Library to split data
from sklearn.model_selection import train_test_split

# library to import to standardize the data
from sklearn.preprocessing import StandardScaler

# To import different metrics
from sklearn.metrics import explained_variance_score, mean_squared_error, r2_score, mean_absolute_error

# Importing classback API
from tensorflow.keras import callbacks

# Importing tensorflow library
import tensorflow as tf

# importing different functions to build models
from tensorflow.keras.layers import Dense, Dropout,InputLayer
from tensorflow.keras.models import Sequential

# Importing Batch Normalization
from tensorflow.keras.layers import BatchNormalization

# Importing backend
from tensorflow.keras import backend

# Importing shffule
from random import shuffle
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# Importing optimizers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import RMSprop

# Library to avoid the warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### **Reading the Dataset**

# %%
#Since data is in form of excel file we have to use pandas pd.read_excel to load the data.
data = pd.read_excel('Data.xlsx')

# %% [markdown]
# #### Print the first five rows of the data

# %%
data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
#Information about the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10682 entries, 0 to 10681
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10682 non-null  object
#  1   Date_of_Journey  10682 non-null  object
#  2   Source           10682 non-null  object
#  3   Destination      10682 non-null  object
#  4   Route            10681 non-null  object
#  5   Dep_Time         10682 non-null  object
#  6   Arrival_Time     10682 non-null  object
#  7   Duration         10682 non-null  object
#  8   Total_Stops      10681 non-null  object
#  9   Additional_Info  10682 non-null  object
#  10  Price            10682 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.1+ KB

# %%
#Checking the shape of the data
data.shape
# Out:
# (10682, 11)

# %%
#finding the null values
data.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
# Checking where the null value present
data[data['Route'].isna()]
# Out:
#         Airline Date_of_Journey Source Destination Route Dep_Time  \
# 9038  Air India       6/05/2019  Delhi      Cochin   NaN    09:45
#
#       Arrival_Time Duration Total_Stops Additional_Info  Price
# 9038  09:25 07 May  23h 40m         NaN         No info   7480

# %% [markdown]
# * Those 2 values belong to a single row so we can drop that row

# %%
#drop the null values
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# dtype: int64

# %%
#Checking the dtypes of the variables in the data
data.dtypes
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# dtype: object

# %% [markdown]
# * The dtypes of 'Date_of_Journey','Dep_Time',and 'Arrival_Time' is in object, so firstly converting it into datetime dtype

# %%
# Creating a function to convert those columns into datetime dtype
def To_Datetime(data,column):
    data[column] = pd.to_datetime(data[column])
    return data[column]

# %%
# convert the columns we want into datetime
To_Datetime(data,'Date_of_Journey')
To_Datetime(data,'Dep_Time')
To_Datetime(data,'Arrival_Time')
# Out:
# 0       2023-03-22 01:10:00
# 1       2023-11-05 13:15:00
# 2       2023-06-10 04:25:00
# 3       2023-11-05 23:30:00
# 4       2023-11-05 21:35:00
#                 ...
# 10677   2023-11-05 22:25:00
# 10678   2023-11-05 23:20:00
# 10679   2023-11-05 11:20:00
# 10680   2023-11-05 14:10:00
# 10681   2023-11-05 19:15:00
# Name: Arrival_Time, Length: 10681, dtype: datetime64[ns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10681 entries, 0 to 10681
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10681 non-null  object
#  1   Date_of_Journey  10681 non-null  datetime64[ns]
#  2   Source           10681 non-null  object
#  3   Destination      10681 non-null  object
#  4   Route            10681 non-null  object
#  5   Dep_Time         10681 non-null  datetime64[ns]
#  6   Arrival_Time     10681 non-null  datetime64[ns]
#  7   Duration         10681 non-null  object
#  8   Total_Stops      10681 non-null  object
#  9   Additional_Info  10681 non-null  object
#  10  Price            10681 non-null  int64
# dtypes: datetime64[ns](3), int64(1), object(7)
# memory usage: 1001.3+ KB

# %%
data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-01-05   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-09-06     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-12-05   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-01-03  Banglore   New Delhi        BLR → NAG → DEL
#
#              Dep_Time        Arrival_Time Duration Total_Stops  \
# 0 2023-11-05 22:20:00 2023-03-22 01:10:00   2h 50m    non-stop
# 1 2023-11-05 05:50:00 2023-11-05 13:15:00   7h 25m     2 stops
# 2 2023-11-05 09:25:00 2023-06-10 04:25:00      19h     2 stops
# 3 2023-11-05 18:05:00 2023-11-05 23:30:00   5h 25m      1 stop
# 4 2023-11-05 16:50:00 2023-11-05 21:35:00   4h 45m      1 stop
#
#   Additional_Info  Price
# 0         No info   3897
# 1         No info   7662
# 2         No info  13882
# 3         No info   6218
# 4         No info  13302

# %% [markdown]
# * We can extract day and month from Date_of_journey and store it in two other columns.

# %%
# creating new columns
data['Day_of_Journey'] = data['Date_of_Journey'].dt.day
data['Month_of_Journey'] = data['Date_of_Journey'].dt.month

# %% [markdown]
# * Now using Dep_Time and Arrival_Time we can extract hour and minute from both the variables

# %% [raw]
# .dt.hour method will extract only day of that Hour
#
# .dt.minute method will extract only month of that Minute

# %%
data["Date_of_Journey"].min(), data["Date_of_Journey"].max()
# Out:
# (Timestamp('2019-01-03 00:00:00'), Timestamp('2019-12-06 00:00:00'))

# %%
# Extracting hour and minute values from Dep_time variable
data['Dep_hour'] = data['Dep_Time'].dt.hour
data['Dep_minute'] = data['Dep_Time'].dt.minute

# Extracting hour value from Dep_time variable
data['Arrival_hour'] = data['Arrival_Time'].dt.hour
data['Arrival_minute'] = data['Arrival_Time'].dt.minute

# %% [markdown]
# * After extacting required data from Date_of_Journey, Dep_Time, and Arrival_Time we can drop these variables

# %%
data.drop(['Date_of_Journey','Dep_Time','Arrival_Time'],axis=1,inplace=True)

# %%
data
# Out:
#            Airline    Source Destination                  Route Duration  \
# 0           IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1        Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2      Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3           IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4           IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
# ...            ...       ...         ...                    ...      ...
# 10677     Air Asia   Kolkata    Banglore              CCU → BLR   2h 30m
# 10678    Air India   Kolkata    Banglore              CCU → BLR   2h 35m
# 10679  Jet Airways  Banglore       Delhi              BLR → DEL       3h
# 10680      Vistara  Banglore   New Delhi              BLR → DEL   2h 40m
# 10681    Air India     Delhi      Cochin  DEL → GOI → BOM → COK   8h 20m
#
#       Total_Stops Additional_Info  Price  Day_of_Journey  Month_of_Journey  \
# 0        non-stop         No info   3897              24                 3
# 1         2 stops         No info   7662               5                 1
# 2         2 stops         No info  13882               6                 9
# 3          1 stop         No info   6218               5                12
# 4          1 stop         No info  13302               3                 1
# ...           ...             ...    ...             ...               ...
# 10677    non-stop         No info   4107               4                 9
# 10678    non-stop         No info   4145              27                 4
# 10679    non-stop         No info   7229              27                 4
# 10680    non-stop         No info  12648               3                 1
# 10681     2 stops         No info  11753               5                 9
#
#        Dep_hour  Dep_minute  Arrival_hour  Arrival_minute
# 0            22          20             1              10
# 1             5          50            13              15
# 2             9          25             4              25
# 3            18           5            23              30
# 4            16          50            21              35
# ...         ...         ...           ...             ...
# 10677        19          55            22              25
# 10678        20          45            23              20
# 10679         8          20            11              20
# 10680        11          30            14              10
# 10681        10          55            19              15
#
# [10681 rows x 14 columns]

# %% [markdown]
# * Lets Apply pre-processing on duration column,Separate Duration hours and minute from duration

# %%
t = "7h 50m"

h = int(t.split("h")[0])
m = int(t.split("m")[0].split()[-1])

d = h + m/60
d
# Out:
# 7.833333333333333

# %%
duration=list(data['Duration'])
for i in range(len(duration)):
    if len(duration[i].split(' '))==2:
        pass
    else:
        if 'h' in duration[i]: # Check if duration contains only hour
             duration[i]=duration[i] + ' 0m' # Adds 0 minute
        else:
             duration[i]='0h '+ duration[i]

duration_hours = []
duration_mins = []
for i in range(len(duration)):
    duration_hours.append(int(duration[i].split(sep = "h")[0]))    # Extract hours from duration
    duration_mins.append(int(duration[i].split(sep = "m")[0].split()[-1]))   # Extracts only minutes from duration

# %%
# Adding duration_hours and duration_mins list to train_data dataframe

# data["Duration_hours"] = duration_hours
# data["Duration_mins"] = duration_mins

total_duration = [round(x + y/60, 2) for x ,y in zip(duration_hours, duration_mins)]

# %%
#Dropping Duration variable as we have extracted both hours and mins from it
# data.drop(["Duration"], axis = 1, inplace = True)
data["Duration"] = total_duration

# %%
data.head()
# Out:
#        Airline    Source Destination                  Route  Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL      2.83
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR      7.42
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK     19.00
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR      5.42
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL      4.75
#
#   Total_Stops Additional_Info  Price  Day_of_Journey  Month_of_Journey  \
# 0    non-stop         No info   3897              24                 3
# 1     2 stops         No info   7662               5                 1
# 2     2 stops         No info  13882               6                 9
# 3      1 stop         No info   6218               5                12
# 4      1 stop         No info  13302               3                 1
#
#    Dep_hour  Dep_minute  Arrival_hour  Arrival_minute
# 0        22          20             1              10
# 1         5          50            13              15
# 2         9          25             4              25
# 3        18           5            23              30
# 4        16          50            21              35

# %%
data.dtypes
# Out:
# Airline              object
# Source               object
# Destination          object
# Route                object
# Duration            float64
# Total_Stops          object
# Additional_Info      object
# Price                 int64
# Day_of_Journey        int64
# Month_of_Journey      int64
# Dep_hour              int64
# Dep_minute            int64
# Arrival_hour          int64
# Arrival_minute        int64
# dtype: object

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# #### Univariate Analysis

# %%
# function to create labeled barplots


def labeled_barplot(data, feature, perc=False, n=None):
    """
    Barplot with percentage at the top

    data: dataframe
    feature: dataframe column
    perc: whether to display percentages instead of count (default is False)
    n: displays the top n category levels (default is None, i.e., display all levels)
    """

    total = len(data[feature])  # length of the column
    count = data[feature].nunique()
    if n is None:
        plt.figure(figsize=(count + 1, 5))
    else:
        plt.figure(figsize=(n + 1, 5))

    plt.xticks(rotation=90, fontsize=15)
    ax = sns.countplot(
        data=data,
        x=feature,
        palette="Paired",
        order=data[feature].value_counts().index[:n].sort_values(),
    )

    for p in ax.patches:
        if perc == True:
            label = "{:.1f}%".format(
                100 * p.get_height() / total
            )  # percentage of each class of the category
        else:
            label = p.get_height()  # count of each level of the category

        x = p.get_x() + p.get_width() / 2  # width of the plot
        y = p.get_height()  # height of the plot

        ax.annotate(
            label,
            (x, y),
            ha="center",
            va="center",
            size=12,
            xytext=(0, 5),
            textcoords="offset points",
        )  # annotate the percentage

    plt.show()  # show the plot

# %% [markdown]
# ### `Airline`

# %%
labeled_barplot(data, "Airline", perc=True)

# %% [markdown]
# * From the above bar plot we can see most of them have opted Jet Airways as their Airline for transportation

# %% [markdown]
# ### `Total Stops`

# %%
labeled_barplot(data, "Total_Stops", perc=True)

# %% [markdown]
# * Most of the airlines runs with maximum of single stop during the journey

# %% [markdown]
# ### `Source`

# %%
labeled_barplot(data, "Source", perc=True)

# %% [markdown]
# * Most of flights are departing from the capital city of India(Delhi)

# %% [markdown]
# ### `Destination`

# %%
labeled_barplot(data, "Destination", perc=True)

# %%
#New Delhi and Delhi can be the same so we will merge them
data['Destination'].replace('New Delhi','Delhi',inplace=True)

# %%
labeled_barplot(data, "Destination", perc=True)

# %% [markdown]
# * From the above plot we can observe most of the filghts are going to Cochin

# %% [markdown]
# ### `Additional_Info`

# %%
labeled_barplot(data, "Additional_Info", perc=True)

# %% [markdown]
# * As most of the Additional_Info (80%) variable contains No_info so we can drop this from the data

# %%
data['Route'].value_counts()
# Out:
# DEL → BOM → COK          2376
# BLR → DEL                1552
# CCU → BOM → BLR           979
# CCU → BLR                 724
# BOM → HYD                 621
#                          ...
# CCU → RPR → HYD → BLR       1
# CCU → VTZ → BLR             1
# CCU → IXZ → MAA → BLR       1
# BOM → COK → MAA → HYD       1
# BOM → BBI → HYD             1
# Name: Route, Length: 127, dtype: int64

# %% [markdown]
# * Route and Total_Stops are related to each other so we can drop Route variable.
# * Since there is not much information from the Additional_info variable, we will drop the Additional_info variable.

# %%
data.drop(["Route", "Additional_Info"], axis = 1, inplace = True)

# %%
data.head()
# Out:
#        Airline    Source Destination  Duration Total_Stops  Price  \
# 0       IndiGo  Banglore       Delhi      2.83    non-stop   3897
# 1    Air India   Kolkata    Banglore      7.42     2 stops   7662
# 2  Jet Airways     Delhi      Cochin     19.00     2 stops  13882
# 3       IndiGo   Kolkata    Banglore      5.42      1 stop   6218
# 4       IndiGo  Banglore       Delhi      4.75      1 stop  13302
#
#    Day_of_Journey  Month_of_Journey  Dep_hour  Dep_minute  Arrival_hour  \
# 0              24                 3        22          20             1
# 1               5                 1         5          50            13
# 2               6                 9         9          25             4
# 3               5                12        18           5            23
# 4               3                 1        16          50            21
#
#    Arrival_minute
# 0              10
# 1              15
# 2              25
# 3              30
# 4              35

# %%
# As this is case of Ordinal Categorical type we perform LabelEncoder
# Here Values are assigned with corresponding keys

data.replace({"non-stop": 0, "1 stop": 1, "2 stops": 2, "3 stops": 3, "4 stops": 4}, inplace = True)

# %% [markdown]
# ### Bivariate analysis

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(
    data.corr(method = "spearman"), annot=True, vmin=-1, vmax=1, fmt=".2f", cmap="Spectral"
)
plt.show()

# %% [markdown]
# * Duration hours and Total stops are highly correlated to target column.
# * Total stops and Duration hours are highly positive correlated to target column.

# %% [markdown]
# ### `Airline` vs `Price`

# %%
plt.figure(figsize=(15,8))
a=sns.boxplot(x='Price',y='Airline',data=data.sort_values('Price',ascending=False),orient="h")

# %% [markdown]
# - Jet Airways Business is charging high price when comparing with other Airlines
# - Apart from the Jet Airways Business Airline almost all are having similar median.

# %%
Highest_airline_price= data[data['Airline']=='Jet Airways Business']
Highest_airline_price
# Out:
#                     Airline    Source Destination  Duration  Total_Stops  \
# 657    Jet Airways Business  Banglore       Delhi      5.00            1
# 2923   Jet Airways Business  Banglore       Delhi      5.67            1
# 5371   Jet Airways Business  Banglore       Delhi      6.67            1
# 7350   Jet Airways Business     Delhi      Cochin      8.33            2
# 9714   Jet Airways Business     Delhi      Cochin      8.33            2
# 10363  Jet Airways Business  Banglore       Delhi      4.67            1
#
#        Price  Day_of_Journey  Month_of_Journey  Dep_hour  Dep_minute  \
# 657    52229               3                 1         5          45
# 2923   79512               3                 1         5          45
# 5371   62427               3                 1         5          45
# 7350   46490               3                 3        20           5
# 9714   52285               3                 6        20           5
# 10363  57209               3                 1         9          45
#
#        Arrival_hour  Arrival_minute
# 657              10              45
# 2923             11              25
# 5371             12              25
# 7350              4              25
# 9714              4              25
# 10363            14              25

# %% [markdown]
# * We can see the price of the Jet Airways Business Airline having an average price of 50 thousand Rupees

# %% [markdown]
# ### `Total Stops` vs `Price`

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x='Total_Stops',y='Price',data=data.sort_values('Price',ascending=False))
# Out:
# <Axes: xlabel='Total_Stops', ylabel='Price'>

# %% [markdown]
# * Prices of Airline having different stops are almost equal and mainly the price depends on which Airline we are choosing to travell

# %%
import plotly.express as px

fig = (
    px.scatter(
        data,
        x = "Month_of_Journey",
        y = "Price",
        template = "presentation",
        width = 900,
        height = 400
    )
    .show()
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d0fcf071-8c50-4c21-b4f9-84c639e8bf00" class="plotly-graph-div" style="height:400px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d0fcf071-8c50-4c21-b4f9-84c639e8bf00")) {                    Plotly.newPlot(                        "d0fcf071-8c50-4c21-b4f9-84c639e8bf00",                        [{"hovertemplate":"Month_of_Journey=%{x}\u003cbr\u003ePrice=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#1F77B4","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[3,1,9,12,1,6,12,1,12,5,1,4,6,9,4,3,4,12,12,5,6,3,3,1,6,9,1,5,6,6,6,1,6,6,5,6,5,5,6,3,5,3,5,6,3,3,5,3,5,6,9,1,3,6,3,3,1,6,6,6,6,3,3,5,5,6,4,6,5,12,1,9,6,6,3,9,3,3,6,3,9,3,6,6,5,6,6,6,1,5,5,6,12,6,4,6,5,3,6,12,5,9,6,12,1,5,3,3,9,5,3,12,12,6,6,5,6,3,12,9,9,3,6,1,12,5,12,6,6,3,3,6,12,6,5,5,6,6,5,3,9,6,6,9,5,5,3,3,6,9,3,3,6,12,5,9,6,3,12,6,1,3,9,9,12,5,3,5,3,5,3,4,9,6,6,12,3,5,6,5,1,3,5,6,12,6,6,6,3,12,3,3,6,6,12,6,12,6,3,3,3,3,4,5,3,4,3,6,5,5,12,6,6,3,1,6,9,1,12,9,12,12,3,9,9,6,3,4,5,5,3,12,5,9,1,1,6,5,3,6,3,6,9,12,3,4,9,5,6,6,3,1,5,3,3,3,9,6,6,3,3,3,3,9,5,3,6,12,1,6,1,12,1,6,9,3,3,12,9,6,12,3,5,6,6,5,12,6,5,12,3,3,6,6,5,6,3,3,6,9,3,6,12,6,9,3,3,6,6,4,5,3,12,3,6,6,5,6,1,3,6,9,6,12,1,5,5,6,3,3,9,3,9,12,5,6,9,3,6,5,6,5,9,6,9,6,5,12,9,4,4,5,6,1,3,1,3,3,6,6,9,3,6,6,3,5,12,3,9,9,4,5,9,3,3,9,3,12,3,3,6,9,9,1,6,3,1,6,5,5,1,9,5,3,5,6,1,3,9,6,12,3,6,9,6,6,5,4,3,12,5,12,5,3,5,3,12,5,6,9,5,5,5,12,5,6,3,5,9,6,12,9,1,4,1,5,3,4,9,6,4,12,5,3,9,6,6,1,5,1,9,1,6,4,6,5,3,6,5,6,3,1,4,9,6,12,6,9,3,3,3,3,6,6,9,3,3,5,3,5,12,5,5,9,4,6,1,5,1,3,1,1,6,6,3,6,6,1,5,12,9,3,5,6,3,5,9,9,5,1,1,9,3,6,6,3,5,5,3,4,3,4,5,5,3,1,5,5,5,4,6,6,6,3,6,9,6,1,6,1,5,4,6,3,3,9,6,12,1,5,4,3,3,9,6,1,9,9,6,5,9,12,6,4,12,1,6,5,6,3,5,6,3,3,5,9,1,1,6,6,4,5,4,5,3,6,5,3,9,3,5,1,4,5,9,5,3,6,1,6,5,4,5,3,1,3,9,1,1,9,1,3,6,3,6,9,5,3,3,1,12,3,6,6,6,12,6,12,3,5,1,6,6,1,3,3,3,4,5,6,5,4,12,5,5,5,3,6,6,12,9,3,6,5,9,3,3,1,5,6,9,3,9,9,4,5,4,3,5,12,3,5,3,6,9,5,6,6,5,3,5,5,9,1,5,12,3,1,3,6,3,6,3,3,12,5,9,3,6,5,9,6,1,3,3,3,5,9,3,6,1,12,3,3,3,1,3,3,12,3,3,6,5,6,5,4,1,3,12,6,5,3,4,12,6,9,1,4,5,9,5,6,1,12,9,9,6,4,5,6,1,6,5,1,9,4,5,3,3,6,3,6,6,3,9,5,9,5,6,9,6,5,3,9,3,5,4,5,5,6,3,3,6,1,6,1,3,6,5,3,9,6,9,9,5,1,9,5,1,3,3,1,12,3,3,6,5,1,5,3,5,5,5,6,6,6,5,5,3,12,6,9,9,9,3,5,1,5,1,5,6,9,9,9,9,5,6,1,5,6,12,6,6,9,5,3,6,6,5,5,9,9,5,6,6,6,5,3,1,1,3,4,6,12,5,9,3,12,6,3,3,6,5,1,6,3,3,6,3,1,6,5,6,5,9,5,6,6,5,9,6,6,9,5,5,3,3,5,3,9,12,9,9,1,5,5,3,4,9,4,5,4,5,1,6,3,3,12,6,12,6,12,3,1,3,6,3,3,3,1,3,3,9,9,3,6,1,9,6,6,9,9,12,5,5,3,1,12,5,12,3,6,3,3,3,12,5,3,5,1,1,5,5,6,5,4,5,9,6,6,3,1,12,9,3,1,12,1,6,9,12,12,9,3,6,5,6,5,5,3,6,3,3,4,12,12,5,5,5,5,3,5,6,9,1,12,9,6,3,6,6,5,3,6,3,6,3,4,6,6,5,3,1,12,5,5,3,9,5,1,9,5,6,6,4,12,3,9,5,9,3,5,3,1,1,5,9,5,6,5,6,9,5,6,6,6,5,1,3,6,5,5,5,6,9,6,3,3,6,1,6,6,3,1,1,12,3,3,3,6,6,12,9,6,6,4,1,5,12,3,1,1,1,6,6,3,5,3,12,6,9,5,6,6,1,5,12,3,6,6,5,6,6,6,3,3,9,3,5,5,6,6,6,12,5,3,6,9,5,3,12,3,6,5,9,5,3,1,4,12,5,3,6,9,6,6,5,6,9,3,5,3,1,6,9,5,3,9,3,6,3,4,12,5,3,12,1,4,3,6,12,6,3,9,1,5,5,1,3,3,9,5,5,3,5,6,1,5,4,9,1,5,6,5,3,6,9,12,6,6,5,5,12,9,9,4,1,5,6,1,5,3,12,5,5,1,4,6,6,4,4,9,3,5,6,3,9,5,12,1,5,3,6,1,5,5,4,3,3,5,4,3,3,5,6,6,1,6,5,9,5,12,9,6,1,9,5,3,3,5,1,5,9,3,6,6,12,12,3,1,5,3,5,3,3,6,3,9,5,6,3,6,5,9,3,1,1,1,5,6,3,9,6,6,6,9,9,12,5,5,1,9,5,5,6,4,5,6,5,6,5,5,9,3,6,3,5,5,3,5,6,6,6,9,4,1,5,5,3,9,3,3,5,3,5,6,9,4,5,9,1,1,9,6,6,5,9,3,5,12,5,5,12,1,3,5,6,3,1,1,9,6,5,6,5,3,12,3,5,3,3,5,6,12,5,6,4,9,6,6,5,9,3,12,6,3,6,3,4,9,9,6,6,12,3,9,6,6,6,3,9,5,6,6,3,5,4,5,3,1,5,1,3,5,1,6,3,12,6,9,5,6,9,5,6,5,1,4,1,3,9,6,9,6,9,9,3,6,6,12,3,4,9,6,5,6,12,12,6,5,1,3,3,3,3,3,6,3,9,9,5,9,6,6,1,9,1,3,12,5,6,12,5,5,1,5,5,3,3,6,5,1,5,5,6,3,9,5,5,9,12,4,12,5,3,1,3,1,5,6,9,5,6,12,9,12,1,9,9,6,9,9,5,3,3,5,9,9,5,6,9,6,9,3,5,12,12,3,12,6,4,9,3,1,3,3,3,6,3,6,12,5,6, ...

# %%
## Storing required categorical variables in cat_dat to apply dummification
cat_data = ["Airline",'Source','Destination']

# %%
##Splitting Independent and dependent variable in X and Y respectively
X = data.drop(['Price'],axis=1)
Y = data[['Price']]

print(X.shape)
print(Y.shape)
print(type(X))
# Out:
# (10681, 11)
# (10681, 1)
# <class 'pandas.core.frame.DataFrame'>

# %%
# Splitting the dataset into the Training and Testing set.
X_big, X_test, y_big, y_test = train_test_split(X,Y, test_size = 0.1, random_state = 5,shuffle = True)

# %%
# Splitting the dataset into the Training and validation set.
X_train, X_val, y_train, y_val = train_test_split(X_big,y_big, test_size = 0.3, random_state = 5,shuffle = True)

# %%
X_train.head()
# Out:
#                 Airline    Source Destination  Duration  Total_Stops  \
# 6603          Air India   Kolkata    Banglore     12.42            1
# 3591          Air India   Kolkata    Banglore     11.25            1
# 2831             IndiGo  Banglore       Delhi      2.83            0
# 1396             IndiGo     Delhi      Cochin      5.42            1
# 2045  Multiple carriers     Delhi      Cochin      7.58            1
#
#       Day_of_Journey  Month_of_Journey  Dep_hour  Dep_minute  Arrival_hour  \
# 6603               5                 9        20          30             8
# 3591               4                 1         9          50            21
# 2831               3                 9         5          30             8
# 1396               4                 6         2           0             7
# 2045               6                 1        14          55            22
#
#       Arrival_minute
# 6603              55
# 3591               5
# 2831              20
# 1396              25
# 2045              30

# %% [markdown]
# **Normalizing**

# %% [markdown]
# ##### **Why scaling is done?**
#
# The numerical columns present in this dataset are having different units (Minutes and Hours), so scaling would help them all be in the same range.
#
# **For example** -
# If you have multiple independent variables like age, salary, and height, With their range as (18–100 Years), (25,000–75,000 Euros), and (1–2 Meters) respectively, feature scaling would help them all to be in the same range.

# %%
## Scaling the data
sc=StandardScaler()
temp = sc.fit(X_train[["Dep_hour","Dep_minute","Arrival_hour","Arrival_minute","Duration"]])
X_train[["Dep_hour","Dep_minute","Arrival_hour","Arrival_minute","Duration"]] = temp.transform(X_train[["Dep_hour","Dep_minute","Arrival_hour","Arrival_minute","Duration"]])
X_test[["Dep_hour","Dep_minute","Arrival_hour","Arrival_minute","Duration"]] = temp.transform(X_test[["Dep_hour","Dep_minute","Arrival_hour","Arrival_minute","Duration"]])
X_val[["Dep_hour","Dep_minute","Arrival_hour","Arrival_minute","Duration"]] = temp.transform(X_val[["Dep_hour","Dep_minute","Arrival_hour","Arrival_minute","Duration"]])

# %%
X_train.head()
# Out:
#                 Airline    Source Destination  Duration  Total_Stops  \
# 6603          Air India   Kolkata    Banglore  0.208587            1
# 3591          Air India   Kolkata    Banglore  0.069819            1
# 2831             IndiGo  Banglore       Delhi -0.928842            0
# 1396             IndiGo     Delhi      Cochin -0.621653            1
# 2045  Multiple carriers     Delhi      Cochin -0.365464            1
#
#       Day_of_Journey  Month_of_Journey  Dep_hour  Dep_minute  Arrival_hour  \
# 6603               5                 9  1.317411    0.309000     -0.791323
# 3591               4                 1 -0.602842    1.374855      1.113619
# 2831               3                 9 -1.301116    0.309000     -0.791323
# 1396               4                 6 -1.824821   -1.289783     -0.937857
# 2045               6                 1  0.270000    1.641319      1.260153
#
#       Arrival_minute
# 6603        1.852886
# 3591       -1.185136
# 2831       -0.273729
# 1396        0.030073
# 2045        0.333875

# %% [markdown]
# Since we are solving the regression module, we will scale the target variable. One of the reasons to scale the data is to reduce the time complexity for updating the weights during the backpropagation, which uses the derivatives.
#
# For classification problem, there is no need of scaling the target variable.

# %%
# Scaling the Target variable (contionous variable)
y_train = sc.fit_transform(y_train)
y_val_scale = sc.transform(y_val)

# %% [markdown]
# **Categorical Encoding**

# %%
# Using pd.get dummies to encode the categorical columns in the data
X_train = pd.get_dummies(X_train,columns=cat_data,drop_first= True)
X_test = pd.get_dummies(X_test,columns=cat_data,drop_first= True)
X_val = pd.get_dummies(X_val,columns=cat_data,drop_first= True)

# %%
# Checking the shape
print(X_train.shape)
print(X_val.shape)
print(y_train.shape)
print(y_val.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (6728, 26)
# (2884, 25)
# (6728, 1)
# (2884, 1)
# (1069, 24)
# (1069, 1)

# %% [markdown]
# Since we have different number of columns in train, test and validation, we will use align function to create dummy variables with all values of zero's in it.
#
# Align method aligns two objects on their axes with the specified join method. This method is helpful when we want to synchronize a dataframe with another dataframe.

# %%
X_train,X_test = X_train.align(X_test,join='outer',axis=1,fill_value=0)
X_train,X_val = X_train.align(X_val,join='outer',axis=1,fill_value=0)

# %%
# Checking the shape
print(X_train.shape)
print(X_val.shape)
print(y_train.shape)
print(y_val.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (6728, 26)
# (2884, 26)
# (6728, 1)
# (2884, 1)
# (1069, 26)
# (1069, 1)

# %% [markdown]
# ### Model performance check
#
# * We will be using metric functions defined in sklearn for RMSE, MAE, and $R^2$.
#
# * We will define functions to calculate adjusted $R^2$
# * We will create a function that will print out all the above metrics in one go.

# %% [markdown]
# # Model Building
#
# - We will now start with the model building process.
# - We will create a model.
#  - Three hidden layer with ReLU as activation function.
#  - Output layer with 1 nodes (For regression problem )

# %% [markdown]
# #### Model-1

# %%
backend.clear_session()
#Fixing the seed for random number generators so that we can ensure we receive the same output everytime
np.random.seed(42)
import random
random.seed(42)
tf.random.set_seed(42)

# %%
# Initializing the model
model = Sequential()

# Adding input layer with 64 neurons, relu as activation function and, he_uniform as weight initializer.
model.add(Dense(64, activation='relu', kernel_initializer='he_uniform', input_shape=(26,)))

# Adding the first hidden layer with 32 neurons, relu as activation function and, he_uniform as weight initializer
model.add(Dense(32, activation='relu', kernel_initializer='he_uniform'))

# Adding the second hidden layer with 32 neurons, relu as activation function and, he_uniform as weight initializer
model.add(Dense(32, activation='relu', kernel_initializer='he_uniform'))

# Adding the output layer with one neuron and linear as activation
model.add(Dense(1, activation='linear'))

# %%
# Model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                1728
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 32)                1056
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 4897 (19.13 KB)
# Trainable params: 4897 (19.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# **Observations**
# - The summary of the model shows each layer's name, type, output shape, and the number of parameters at that particular layer.
# - It also shows the total number of trainable and non-trainable parameters in the model. A parameter whose value is learned while training the model is called a trainable parameter otherwise it is called a non-trainable parameter.
# - In the first layer total parameters are calculated by the number of neurons in the hidden layer multiplied by the number of variables fed to neural networks plus bias. (27*64)+64 = 1792
# - In the next layer the parameters are calculated by the number of outputs from the previous layer multiplied by the number of neurons in the second layer plus bias. (64*32)+32 =2080
# - You can calculate for the third layer and final layer.

# %%
# Initializing the Optimizer
optimizer = RMSprop( learning_rate=0.001)

# Compiling the model with 'mse' as loss function and metrics
model.compile(loss='mse',
              optimizer=optimizer,
              metrics=['mae'])

# Fitting the model on train and validation with 50 epochs
history = model.fit(X_train, y_train, validation_data=(X_val, y_val_scale), epochs=50)
# Out:
# Epoch 1/50
# 211/211 [==============================] - 6s 5ms/step - loss: 0.6544 - mae: 0.5601 - val_loss: 0.5023 - val_mae: 0.5384
# Epoch 2/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.4780 - mae: 0.4675 - val_loss: 0.3845 - val_mae: 0.4202
# Epoch 3/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.4332 - mae: 0.4438 - val_loss: 0.3801 - val_mae: 0.4619
# Epoch 4/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.3994 - mae: 0.4338 - val_loss: 0.3893 - val_mae: 0.4644
# Epoch 5/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.3751 - mae: 0.4191 - val_loss: 0.3653 - val_mae: 0.4323
# Epoch 6/50
# 211/211 [==============================] - 1s 6ms/step - loss: 0.3479 - mae: 0.4088 - val_loss: 0.3087 - val_mae: 0.4001
# Epoch 7/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.3352 - mae: 0.4011 - val_loss: 0.3199 - val_mae: 0.4013
# Epoch 8/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.3201 - mae: 0.3947 - val_loss: 0.2972 - val_mae: 0.3866
# Epoch 9/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.3119 - mae: 0.3897 - val_loss: 0.3014 - val_mae: 0.3976
# Epoch 10/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.3017 - mae: 0.3861 - val_loss: 0.3341 - val_mae: 0.4315
# Epoch 11/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.2940 - mae: 0.3795 - val_loss: 0.3302 - val_mae: 0.4425
# Epoch 12/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.2809 - mae: 0.3744 - val_loss: 0.2739 - val_mae: 0.3704
# Epoch 13/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.2765 - mae: 0.3725 - val_loss: 0.2952 - val_mae: 0.3824
# Epoch 14/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.2681 - mae: 0.3670 - val_loss: 0.2992 - val_mae: 0.3991
# Epoch 15/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.2592 - mae: 0.3645 - val_loss: 0.3113 - val_mae: 0.4054
# Epoch 16/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.2524 - mae: 0.3612 - val_loss: 0.3006 - val_mae: 0.3975
# Epoch 17/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.2475 - mae: 0.3583 - val_loss: 0.2820 - val_mae: 0.3737
# Epoch 18/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.2424 - mae: 0.3542 - val_loss: 0.2896 - val_mae: 0.4046
# Epoch 19/50
# 211/211 [==============================] - 1s 6ms/step - loss: 0.2408 - mae: 0.3547 - val_loss: 0.2992 - val_mae: 0.4175
# Epoch 20/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.2335 - mae: 0.3480 - val_loss: 0.3325 - val_mae: 0.4326
# Epoch 21/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.2318 - mae: 0.3486 - val_loss: 0.3105 - val_mae: 0.3874
# Epoch 22/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.2290 - mae: 0.3447 - val_loss: 0.2877 - val_mae: 0.3797
# Epoch 23/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.2258 - mae: 0.3418 - val_loss: 0.2657 - val_mae: 0.3592
# Epoch 24/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.2222 - mae: 0.3408 - val_loss: 0.2932 - val_mae: 0.3735
# Epoch 25/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.2197 - mae: 0.3377 - val_loss: 0.2757 - val_mae: 0.3815
# Epoch 26/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.2184 - mae: 0.3377 - val_loss: 0.3085 - val_mae: 0.3899
# Epoch 27/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.2184 - mae: 0.3353 - val_loss: 0.2607 - val_mae: 0.3583
# Epoch 28/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.2155 - mae: 0.3341 - val_loss: 0.2569 - val_mae: 0.3514
# Epoch 29/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.2154 - mae: 0.3341 - val_loss: 0.2566 - val_mae: 0.3576
# Epoch 30/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.2130 - mae: 0.3317 - val_loss: 0.2521 - val_mae: 0.3581
# Epoch 31/50
# 211/211 [==============================] - 1s 6ms/step - loss: 0.2100 - mae: 0.3306 - val_loss: 0.2643 - val_mae: 0.3581
# Epoch 32/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.2064 - mae: 0.3291 - val_loss: 0.2911 - val_mae: 0.3762
# Epoch 33/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.2064 - mae: 0.3275 - val_loss: 0.2901 - val_mae: 0.3768
# Epoch 34/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.2053 - mae: 0.3257 - val_loss: 0.2577 - val_mae: 0.3710
# Epoch 35/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.2030 - mae: 0.3244 - val_loss: 0.2859 - val_mae: 0.3849
# Epoch 36/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.2020 - mae: 0.3244 - val_loss: 0.2522 - val_mae: 0.3488
# Epoch 37/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.1989 - mae: 0.3232 - val_loss: 0.2562 - val_mae: 0.3614
# Epoch 38/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.1963 - mae: 0.3193 - val_loss: 0.2645 - val_mae: 0.3563
# Epoch 39/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.1953 - mae: 0.3190 - val_loss: 0.2780 - val_mae: 0.3879
# Epoch 40/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.1960 - mae: 0.3184 - val_loss: 0.2531 - val_mae: 0.3595
# Epoch 41/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.1947 - mae: 0.3161 - val_loss: 0.2784 - val_mae: 0.3706
# Epoch 42/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.1920 - mae: 0.3145 - val_loss: 0.2883 - val_mae: 0.3712
# Epoch 43/50
# 211/211 [==============================] - 1s 6ms/step - loss: 0.1890 - mae: 0.3145 - val_loss: 0.2550 - val_mae: 0.3544
# Epoch 44/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.1903 - mae: 0.3143 - val_loss: 0.2744 - val_mae: 0.3670
# Epoch 45/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.1903 - mae: 0.3134 - val_loss: 0.2629 - val_mae: 0.3522
# Epoch 46/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.1871 - mae: 0.3106 - val_loss: 0.2866 - val_mae: 0.3683
# Epoch 47/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.1872 - mae: 0.3120 - val_loss: 0.2760 - val_mae: 0.3745
# Epoch 48/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.1871 - mae: 0.3112 - val_loss: 0.2761 - val_mae: 0.3626
# Epoch 49/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.1829 - mae: 0.3078 - val_loss: 0.2533 - val_mae: 0.3504
# Epoch 50/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.1818 - mae: 0.3083 - val_loss: 0.2480 - val_mae: 0.3445

# %%
pyplot.title('Loss / Mean Squared Error')
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='validate')
pyplot.legend()
pyplot.show()

# %% [markdown]
# Here the model seems to be overfitted, as the distance between the train curve and validation curve started increasing.

# %%
# Lets predict on validation data
Y_result_scaled= model.predict(X_val)

# As we have scaled the target variable, now after predicting we should inverse the scale and convert it to normal form
Y_result = sc.inverse_transform(Y_result_scaled)
print(Y_result)
# Out:
# 91/91 [==============================] - 0s 2ms/step
# [[ 5198.663 ]
#  [13996.024 ]
#  [ 6426.6875]
#  ...
#  [ 3993.1763]
#  [ 6662.8384]
#  [ 8894.251 ]]

# %%
def adj_r2_score(predictors, targets, predictions):
    r2 = r2_score(targets, predictions)
    n = predictors.shape[0]
    k = predictors.shape[1]
    return 1 - ((1 - r2) * (n - 1) / (n - k - 1))
def model_performance_regression(predictors,target,pred):
  r2 = r2_score(target, pred)  # to compute R-squared
  adjr2 = adj_r2_score(predictors, target, pred)  # to compute adjusted R-squared
  rmse = np.sqrt(mean_squared_error(target, pred))  # to compute RMSE
  mae = mean_absolute_error(target, pred)  # to compute MAE

  df_perf = pd.DataFrame(
        {
            "RMSE": rmse,
            "MAE": mae,
            "R-squared": r2,
            "Adj. R-squared": adjr2,
        },
        index=[0],
    )

  return df_perf

# %%
# Checking model performance on train set
print("Validation Performance\n")
model_train_perf = model_performance_regression(X_val,y_val, Y_result)
model_train_perf
# Out:
# Validation Performance
#           RMSE          MAE  R-squared  Adj. R-squared
# 0  2288.568369  1583.160732   0.743942        0.741611

# %%
# Lets predict on train data
Y_result_train_scaled = model.predict(X_train)

# As we have scaled the target variable, now after predicting we should inverse the scale and convert it to normal form
Y_result_train = sc.inverse_transform(Y_result_train_scaled)
y_train_true = sc.inverse_transform(y_train)
print(Y_result)

# Checking model performance on train set
print("Training Performance\n")
model_train_perf = model_performance_regression(X_train, y_train_true, Y_result_train)
model_train_perf
# Out:
# 211/211 [==============================] - 1s 3ms/step
# [[ 5198.663 ]
#  [13996.024 ]
#  [ 6426.6875]
#  ...
#  [ 3993.1763]
#  [ 6662.8384]
#  [ 8894.251 ]]
# Training Performance
#          RMSE          MAE  R-squared  Adj. R-squared
# 0  1909.17786  1360.685667    0.82741         0.82674

# %% [markdown]
# * Now, let's try using Early stopping and see if we can overcome the overfitting problem, we can also change the optimizer and use Adam.

# %% [markdown]
# #### Model-2

# %% [markdown]
# **Early stopping:**
#
# During training, the model is evaluated on a holdout validation dataset after each epoch. If the performance of the model on the validation dataset starts to degrade or no improvement (e.g. loss begins to increase or accuracy begins to decrease), then the training process is stopped after the certian interations.The model at the time that training is stopped is then used and is known to have good generalization performance.
#
# This procedure is called “early stopping” and is perhaps one of the oldest and most widely used forms of neural network regularization.

# %%
backend.clear_session()
#Fixing the seed for random number generators so that we can ensure we receive the same output everytime
np.random.seed(42)
import random
random.seed(42)
tf.random.set_seed(42)

# %%
# Initializing the model
model_2 = Sequential()

# Adding input layer with 64 neurons, relu as activation function and, he_uniform as weight initializer.
model_2.add(Dense(64, activation='relu',kernel_initializer='he_uniform', input_shape=(26,)))

# Adding the first hidden layer with 32 neurons, relu as activation function and, he_uniform as weight initializer
model_2.add(Dense(32, activation='relu',kernel_initializer='he_uniform'))

# Adding the second hidden layer with 32 neurons, relu as activation function and, he_uniform as weight initializer
model_2.add(Dense(32, activation='relu',kernel_initializer='he_uniform'))

# Adding the output layer with one neuron and linear as activation
model_2.add(Dense(1, activation='linear'))

# %%
# Model summary
model_2.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                1728
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 32)                1056
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 4897 (19.13 KB)
# Trainable params: 4897 (19.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Initializing the Optimizer
optimizer = Adam( learning_rate=0.001)

# Compiling the model with 'mse' as loss function and metrics
model_2.compile(loss='mse',
              optimizer=optimizer,
              metrics=['mae'])

# Defining Early stopping
es_cb = EarlyStopping(monitor='val_loss', min_delta=0.001, patience=5, restore_best_weights = True)

# Fitting the model on train and validation with 50 epochs
history_2 = model_2.fit(X_train, y_train, validation_data=(X_val, y_val_scale), epochs=50,callbacks=es_cb)
# Out:
# Epoch 1/50
# 211/211 [==============================] - 2s 5ms/step - loss: 0.7455 - mae: 0.5936 - val_loss: 0.4380 - val_mae: 0.4590
# Epoch 2/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.4513 - mae: 0.4466 - val_loss: 0.3830 - val_mae: 0.4235
# Epoch 3/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.3901 - mae: 0.4188 - val_loss: 0.3683 - val_mae: 0.4269
# Epoch 4/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.3582 - mae: 0.4114 - val_loss: 0.3250 - val_mae: 0.4102
# Epoch 5/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.3307 - mae: 0.3949 - val_loss: 0.3118 - val_mae: 0.3876
# Epoch 6/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.3212 - mae: 0.3983 - val_loss: 0.2950 - val_mae: 0.3856
# Epoch 7/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.2927 - mae: 0.3823 - val_loss: 0.3017 - val_mae: 0.3983
# Epoch 8/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.2836 - mae: 0.3819 - val_loss: 0.2829 - val_mae: 0.3776
# Epoch 9/50
# 211/211 [==============================] - 1s 6ms/step - loss: 0.2744 - mae: 0.3755 - val_loss: 0.3284 - val_mae: 0.4328
# Epoch 10/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.2674 - mae: 0.3746 - val_loss: 0.2852 - val_mae: 0.3927
# Epoch 11/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.2589 - mae: 0.3710 - val_loss: 0.2700 - val_mae: 0.3756
# Epoch 12/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.2498 - mae: 0.3639 - val_loss: 0.2712 - val_mae: 0.3758
# Epoch 13/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.2451 - mae: 0.3593 - val_loss: 0.2744 - val_mae: 0.3806
# Epoch 14/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.2422 - mae: 0.3583 - val_loss: 0.2692 - val_mae: 0.3676
# Epoch 15/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.2365 - mae: 0.3532 - val_loss: 0.2651 - val_mae: 0.3716
# Epoch 16/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.2351 - mae: 0.3524 - val_loss: 0.2777 - val_mae: 0.3770
# Epoch 17/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.2320 - mae: 0.3505 - val_loss: 0.2836 - val_mae: 0.3820
# Epoch 18/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.2301 - mae: 0.3500 - val_loss: 0.2737 - val_mae: 0.3884
# Epoch 19/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.2236 - mae: 0.3442 - val_loss: 0.2682 - val_mae: 0.3624
# Epoch 20/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.2248 - mae: 0.3472 - val_loss: 0.2793 - val_mae: 0.4007

# %%
pyplot.title('Loss / Mean Squared Error')
pyplot.plot(history_2.history['loss'], label='train')
pyplot.plot(history_2.history['val_loss'], label='validate')
pyplot.legend()
pyplot.show()

# %% [markdown]
# * The train and validation curves are smooth after using Adam, although they appear to be slightly overfitted.

# %%
# Lets predict on validation data
Y_result_scaled_2= model_2.predict(X_val)

# As we have scaled the target variable, now after predicting we should inverse the scale and should convert to normal form
Y_result2 = sc.inverse_transform(Y_result_scaled_2)
print(Y_result2)
# Out:
# 91/91 [==============================] - 0s 2ms/step
# [[ 7130.077 ]
#  [14447.541 ]
#  [ 6579.683 ]
#  ...
#  [ 4725.3066]
#  [ 6630.81  ]
#  [10008.022 ]]

# %%
# Checking model performance on train set
print("Validation Performance\n")
model_train_perf = model_performance_regression(X_val,y_val, Y_result2)
model_train_perf
# Out:
# Validation Performance
#          RMSE          MAE  R-squared  Adj. R-squared
# 0  2366.20526  1707.877224   0.726274        0.723783

# %%
# Lets predict on train data
Y_result_train_scaled = model_2.predict(X_train)

# As we have scaled the target variable, now after predicting we should inverse the scale and convert it to normal form
Y_result_train = sc.inverse_transform(Y_result_train_scaled)
y_train_true = sc.inverse_transform(y_train)
print(Y_result)

# Checking model performance on train set
print("Training Performance\n")
model_train_perf = model_performance_regression(X_train, y_train_true, Y_result_train)
model_train_perf
# Out:
# 211/211 [==============================] - 0s 2ms/step
# [[ 5198.663 ]
#  [13996.024 ]
#  [ 6426.6875]
#  ...
#  [ 3993.1763]
#  [ 6662.8384]
#  [ 8894.251 ]]
# Training Performance
#           RMSE          MAE  R-squared  Adj. R-squared
# 0  2169.394443  1594.129048   0.777156        0.776291

# %% [markdown]
# Changing the optimizer didn't work, and even the Adj R-square has decreased when compared to previous model.

# %% [markdown]
# * Let's use two Regularization techniques to reduce the overfitting problem.
#
#  - Dropout
#  - BatchNormalization

# %% [markdown]
# #### Model-3

# %% [markdown]
# **Dropout**
#
# Dropout is a regularization technique for neural network models proposed by Srivastava, et al. in their 2014 paper Dropout: A Simple Way to Prevent Neural Networks from Overfitting. Dropout is a technique where randomly selected neurons are ignored during training. They are “dropped-out” randomly.

# %%
backend.clear_session()
#Fixing the seed for random number generators so that we can ensure we receive the same output everytime
np.random.seed(42)
import random
random.seed(42)
tf.random.set_seed(42)

# %%
# Initializing the model
model_3 = Sequential()

# Adding input layer with 64 neurons, relu as activation function and, he_uniform as weight initializer.
model_3.add(Dense(64, activation='relu',kernel_initializer='he_uniform', input_shape=(26,)))

# Adding Dropout with 20%
model_3.add(Dropout(0.2))

# Adding the first hidden layer with 32 neurons, relu as activation function and, he_uniform as weight initializer
model_3.add(Dense(32, activation='relu',kernel_initializer='he_uniform'))

# Adding Dropout with 20%
model_3.add(Dropout(0.2))

# Adding the second hidden layer with 32 neurons, relu as activation function and, he_uniform as weight initializer
model_3.add(Dense(16, activation='relu',kernel_initializer='he_uniform'))

# Adding the output layer with one neuron and linear as activation
model_3.add(Dense(1, activation='linear'))

# %%
# Model summary
model_3.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                1728
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 16)                528
#
#  dense_3 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 4353 (17.00 KB)
# Trainable params: 4353 (17.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Initializing the Optimizer
optimizer = Adam(0.001)

# Compiling the model with 'mse' as loss function and metrics
model_3.compile(loss='mse',
              optimizer=optimizer,
              metrics=['mae'])

# Defining Early stopping
es_cb = callbacks.EarlyStopping(monitor='val_loss', min_delta=0.001, patience=5, restore_best_weights = True)

# Fitting the model on train and validation with 50 epochs
history_3 = model_3.fit(X_train, y_train, validation_data=(X_val, y_val_scale), epochs=50,callbacks=es_cb)
# Out:
# Epoch 1/50
# 211/211 [==============================] - 4s 7ms/step - loss: 2.2762 - mae: 1.0741 - val_loss: 0.8070 - val_mae: 0.7019
# Epoch 2/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.9644 - mae: 0.7419 - val_loss: 0.7558 - val_mae: 0.6787
# Epoch 3/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.8237 - mae: 0.6813 - val_loss: 0.5606 - val_mae: 0.5714
# Epoch 4/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.6790 - mae: 0.6016 - val_loss: 0.4663 - val_mae: 0.5178
# Epoch 5/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.5877 - mae: 0.5614 - val_loss: 0.4193 - val_mae: 0.4785
# Epoch 6/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.5361 - mae: 0.5281 - val_loss: 0.3959 - val_mae: 0.4704
# Epoch 7/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.4964 - mae: 0.5102 - val_loss: 0.3725 - val_mae: 0.4386
# Epoch 8/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.4680 - mae: 0.4993 - val_loss: 0.3696 - val_mae: 0.4476
# Epoch 9/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.4546 - mae: 0.4831 - val_loss: 0.3650 - val_mae: 0.4543
# Epoch 10/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.4132 - mae: 0.4680 - val_loss: 0.3437 - val_mae: 0.4281
# Epoch 11/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.4056 - mae: 0.4662 - val_loss: 0.3509 - val_mae: 0.4370
# Epoch 12/50
# 211/211 [==============================] - 1s 6ms/step - loss: 0.3976 - mae: 0.4568 - val_loss: 0.3300 - val_mae: 0.4202
# Epoch 13/50
# 211/211 [==============================] - 1s 6ms/step - loss: 0.3814 - mae: 0.4498 - val_loss: 0.3333 - val_mae: 0.4377
# Epoch 14/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.3917 - mae: 0.4463 - val_loss: 0.3300 - val_mae: 0.4214
# Epoch 15/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.3753 - mae: 0.4434 - val_loss: 0.3235 - val_mae: 0.4325
# Epoch 16/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.3572 - mae: 0.4334 - val_loss: 0.3160 - val_mae: 0.4195
# Epoch 17/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.3544 - mae: 0.4268 - val_loss: 0.3182 - val_mae: 0.4223
# Epoch 18/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.3568 - mae: 0.4284 - val_loss: 0.3182 - val_mae: 0.4160
# Epoch 19/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.3304 - mae: 0.4185 - val_loss: 0.3089 - val_mae: 0.4197
# Epoch 20/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.3321 - mae: 0.4184 - val_loss: 0.3119 - val_mae: 0.4236
# Epoch 21/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.3290 - mae: 0.4150 - val_loss: 0.3041 - val_mae: 0.4095
# Epoch 22/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.3130 - mae: 0.4053 - val_loss: 0.3044 - val_mae: 0.4111
# Epoch 23/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.3087 - mae: 0.4022 - val_loss: 0.3016 - val_mae: 0.4085
# Epoch 24/50
# 211/211 [==============================] - 1s 6ms/step - loss: 0.3197 - mae: 0.4034 - val_loss: 0.2937 - val_mae: 0.4023
# Epoch 25/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.3223 - mae: 0.4017 - val_loss: 0.2875 - val_mae: 0.3980
# Epoch 26/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.3048 - mae: 0.3941 - val_loss: 0.2975 - val_mae: 0.4145
# Epoch 27/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.3051 - mae: 0.3966 - val_loss: 0.2902 - val_mae: 0.4006
# Epoch 28/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.2829 - mae: 0.3865 - val_loss: 0.2809 - val_mae: 0.3880
# Epoch 29/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.2903 - mae: 0.3894 - val_loss: 0.2866 - val_mae: 0.3911
# Epoch 30/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.2880 - mae: 0.3868 - val_loss: 0.2896 - val_mae: 0.3977
# Epoch 31/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.2905 - mae: 0.3866 - val_loss: 0.2845 - val_mae: 0.3947
# Epoch 32/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.2938 - mae: 0.3842 - val_loss: 0.2753 - val_mae: 0.3800
# Epoch 33/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.2753 - mae: 0.3801 - val_loss: 0.2793 - val_mae: 0.3905
# Epoch 34/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.2788 - mae: 0.3824 - val_loss: 0.2810 - val_mae: 0.3974
# Epoch 35/50
# 211/211 [==============================] - 1s 6ms/step - loss: 0.2794 - mae: 0.3787 - val_loss: 0.2782 - val_mae: 0.3896
# Epoch 36/50
# 211/211 [==============================] - 1s 6ms/step - loss: 0.2888 - mae: 0.3758 - val_loss: 0.2756 - val_mae: 0.3933
# Epoch 37/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.2783 - mae: 0.3757 - val_loss: 0.2740 - val_mae: 0.3834
# Epoch 38/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.2621 - mae: 0.3690 - val_loss: 0.2643 - val_mae: 0.3780
# Epoch 39/50
# 211/211 [==============================] - 1s 4ms/step - loss: 0.2764 - mae: 0.3708 - val_loss: 0.2711 - val_mae: 0.3929
# Epoch 40/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.2659 - mae: 0.3732 - val_loss: 0.2637 - val_mae: 0.3802
# Epoch 41/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.2660 - mae: 0.3665 - val_loss: 0.2653 - val_mae: 0.3816
# Epoch 42/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.2614 - mae: 0.3660 - val_loss: 0.2719 - val_mae: 0.3810
# Epoch 43/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.2602 - mae: 0.3636 - val_loss: 0.2681 - val_mae: 0.3829

# %%
pyplot.title('Loss / Mean Squared Error')
pyplot.plot(history_3.history['loss'], label='train')
pyplot.plot(history_3.history['val_loss'], label='validate')
pyplot.legend()
pyplot.show()

# %% [markdown]
# After using Dropout technique the train and validation curves seems to be smooth.

# %%
Y_result_scaled_3= model_3.predict(X_val)
Y_result_3 = sc.inverse_transform(Y_result_scaled_3)
print(Y_result_3)
# Out:
# 91/91 [==============================] - 0s 2ms/step
# [[ 6376.751 ]
#  [12272.869 ]
#  [ 6552.4565]
#  ...
#  [ 4605.9478]
#  [ 6803.608 ]
#  [ 9165.356 ]]

# %%
# Checking model performance on train set
print("Validation Performance\n")
model_train_perf = model_performance_regression(X_val,y_val, Y_result_3)
model_train_perf
# Out:
# Validation Performance
#           RMSE          MAE  R-squared  Adj. R-squared
# 0  2362.413827  1736.958764   0.727151        0.724668

# %%
# Lets predict on train data
Y_result_train_scaled = model_3.predict(X_train)

# As we have scaled the target variable, now after predicting we should inverse the scale and convert it to normal form
Y_result_train = sc.inverse_transform(Y_result_train_scaled)
y_train_true = sc.inverse_transform(y_train)
# print(Y_result)

# Checking model performance on train set
print("Training Performance\n")
model_train_perf = model_performance_regression(X_train, y_train_true, Y_result_train)
model_train_perf
# Out:
# 211/211 [==============================] - 1s 3ms/step
# Training Performance
#           RMSE          MAE  R-squared  Adj. R-squared
# 0  2233.546227  1661.995128   0.763782        0.762865

# %% [markdown]
# The Adjusted R-Square has increased when compared to the previous model. Now let's try the BatchNormalization technique and see if we can improve the metrics.

# %% [markdown]
# #### Model-4

# %%
backend.clear_session()
#Fixing the seed for random number generators so that we can ensure we receive the same output everytime
np.random.seed(42)
import random
random.seed(42)
tf.random.set_seed(42)

# %%
# Initializing the model
model_4 = Sequential()

# Adding input layer with 64 neurons, relu as activation function and, he_uniform as weight initializer.
model_4.add(Dense(64, activation='relu',kernel_initializer='he_uniform', input_shape=(26,)))
# model_4.add(BatchNormalization())

# Adding the first hidden layer with 32 neurons, relu as activation function and, he_uniform as weight initializer
model_4.add(Dense(32, activation='relu',kernel_initializer='he_uniform'))

# Adding Batch Normalization
model_4.add(BatchNormalization())
model_4.add(Dropout(0.2))
# Adding the second hidden layer with 32 neurons, relu as activation function and, he_uniform as weight initializer
model_4.add(Dense(32, activation='relu',kernel_initializer='he_uniform'))

# Adding the output layer with one neuron and linear as activation
model_4.add(Dense(1, activation='linear'))

# %%
# Model summary
model_4.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                1728
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  batch_normalization (Batch  (None, 32)                128
#  Normalization)
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_2 (Dense)             (None, 32)                1056
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5025 (19.63 KB)
# Trainable params: 4961 (19.38 KB)
# Non-trainable params: 64 (256.00 Byte)
# _________________________________________________________________

# %%
# Initializing the Optimizer
optimizer = Adam(0.001)

# Compiling the model with 'mse' as loss function and metrics
model_4.compile(loss='mse',
              optimizer=optimizer,
              metrics=['mae'])

# Defining Early stopping
es_cb = callbacks.EarlyStopping(monitor='val_loss', min_delta=0.001, patience=5, restore_best_weights = True)

# Fitting the model on train and validation with 50 epochs
history_4 = model_4.fit(X_train, y_train, validation_data=(X_val, y_val_scale), epochs=50,callbacks=es_cb)
# Out:
# Epoch 1/50
# 211/211 [==============================] - 3s 7ms/step - loss: 0.8839 - mae: 0.6751 - val_loss: 0.5220 - val_mae: 0.5352
# Epoch 2/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.5859 - mae: 0.5434 - val_loss: 0.4047 - val_mae: 0.4537
# Epoch 3/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.5177 - mae: 0.4998 - val_loss: 0.3838 - val_mae: 0.4282
# Epoch 4/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.4717 - mae: 0.4748 - val_loss: 0.3519 - val_mae: 0.4198
# Epoch 5/50
# 211/211 [==============================] - 1s 6ms/step - loss: 0.4484 - mae: 0.4668 - val_loss: 0.3503 - val_mae: 0.4049
# Epoch 6/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.4197 - mae: 0.4560 - val_loss: 0.3472 - val_mae: 0.4247
# Epoch 7/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.3948 - mae: 0.4426 - val_loss: 0.3912 - val_mae: 0.4267
# Epoch 8/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.3969 - mae: 0.4417 - val_loss: 0.3569 - val_mae: 0.4014
# Epoch 9/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.3762 - mae: 0.4281 - val_loss: 0.3760 - val_mae: 0.4031
# Epoch 10/50
# 211/211 [==============================] - 1s 7ms/step - loss: 0.3928 - mae: 0.4290 - val_loss: 0.3355 - val_mae: 0.4029
# Epoch 11/50
# 211/211 [==============================] - 1s 7ms/step - loss: 0.3826 - mae: 0.4233 - val_loss: 0.3209 - val_mae: 0.3955
# Epoch 12/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.3556 - mae: 0.4188 - val_loss: 0.3554 - val_mae: 0.3975
# Epoch 13/50
# 211/211 [==============================] - 1s 6ms/step - loss: 0.3479 - mae: 0.4113 - val_loss: 0.3415 - val_mae: 0.4029
# Epoch 14/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.3428 - mae: 0.4089 - val_loss: 0.4139 - val_mae: 0.4046
# Epoch 15/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.3384 - mae: 0.4053 - val_loss: 0.3170 - val_mae: 0.3921
# Epoch 16/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.3374 - mae: 0.4069 - val_loss: 0.3444 - val_mae: 0.3952
# Epoch 17/50
# 211/211 [==============================] - 1s 6ms/step - loss: 0.3376 - mae: 0.4081 - val_loss: 0.3950 - val_mae: 0.4404
# Epoch 18/50
# 211/211 [==============================] - 1s 6ms/step - loss: 0.3259 - mae: 0.4000 - val_loss: 0.4523 - val_mae: 0.4074
# Epoch 19/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.3294 - mae: 0.4029 - val_loss: 0.4158 - val_mae: 0.4043
# Epoch 20/50
# 211/211 [==============================] - 1s 6ms/step - loss: 0.3113 - mae: 0.3969 - val_loss: 0.3226 - val_mae: 0.3952

# %%
pyplot.title('Loss / Mean Squared Error')
pyplot.plot(history_4.history['loss'], label='train')
pyplot.plot(history_4.history['val_loss'], label='validate')
pyplot.legend()
pyplot.show()

# %% [markdown]
# The train and validation curves are smooth. Now let's calculate the metrics.

# %%
Y_result_scaled_4= model_4.predict(X_val)
Y_result_4 = sc.inverse_transform(Y_result_scaled_4)
print(Y_result_4)
# Out:
# 91/91 [==============================] - 0s 3ms/step
# [[ 6034.174 ]
#  [13808.605 ]
#  [ 6463.0005]
#  ...
#  [ 4170.993 ]
#  [ 6304.4263]
#  [10706.644 ]]

# %%
# Checking model performance on train set
print("Validation Performance\n")
model_train_perf = model_performance_regression(X_val,y_val, Y_result_4)
model_train_perf
# Out:
# Validation Performance
#           RMSE          MAE  R-squared  Adj. R-squared
# 0  2587.256827  1801.695672   0.672742        0.669764

# %% [markdown]
# * BatchNormalization technique did not perform well on and even the Adjusted R-square dropped sharply.
# * Let's try to build another model using Dropout with different neural network architecture and see if we can improve the Adjusted R-square.

# %%
# Lets predict on train data
Y_result_train_scaled = model_4.predict(X_train)

# As we have scaled the target variable, now after predicting we should inverse the scale and convert it to normal form
Y_result_train = sc.inverse_transform(Y_result_train_scaled)
y_train_true = sc.inverse_transform(y_train)
# print(Y_result)

# Checking model performance on train set
print("Training Performance\n")
model_train_perf = model_performance_regression(X_train, y_train_true, Y_result_train)
model_train_perf
# Out:
# 211/211 [==============================] - 0s 2ms/step
# Training Performance
#           RMSE          MAE  R-squared  Adj. R-squared
# 0  2458.209923  1710.744148   0.713871        0.712761

# %% [markdown]
# ### Model-5

# %%
backend.clear_session()
#Fixing the seed for random number generators so that we can ensure we receive the same output everytime
np.random.seed(42)
import random
random.seed(42)
tf.random.set_seed(42)

# %%
# Initializing the model
model_5 = Sequential()

# Adding input layer with 64 neurons, relu as activation function and, he_uniform as weight initializer.
model_5.add(Dense(64, activation='relu',kernel_initializer='he_uniform', input_shape=(26,)))

# Adding dropout with ratio of 0.2
model_5.add(Dropout(0.2))

# Adding the first hidden layer with 32 neurons, relu as activation function and, he_uniform as weight initializer
model_5.add(Dense(32, activation='relu',kernel_initializer='he_uniform'))

# Adding dropout with ratio of 0.1
model_5.add(Dropout(0.1))

# Adding the second hidden layer with 16 neurons, relu as activation function and, he_uniform as weight initializer
model_5.add(Dense(16, activation='relu',kernel_initializer='he_uniform'))

# Adding the third hidden layer with 8 neurons, relu as activation function and, he_uniform as weight initializer
model_5.add(Dense(8, activation='relu',kernel_initializer='he_uniform'))

# Adding the output layer with one neuron and linear as activation
model_5.add(Dense(1, activation='linear'))

# %%
# Model summary
model_5.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                1728
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 16)                528
#
#  dense_3 (Dense)             (None, 8)                 136
#
#  dense_4 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 4481 (17.50 KB)
# Trainable params: 4481 (17.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Initializing the Optimizer
optimizer = Adam(0.001)

# Compiling the model with 'mse' as loss function and metrics
model_5.compile(loss='mse',
              optimizer=optimizer,
              metrics=['mae'])

# Adding the callbacks
es_cb = callbacks.EarlyStopping(monitor='val_loss', min_delta=0.001, patience=5, restore_best_weights=True)

# Fitting the model on train and validation with 50 epochs
history_5 = model_5.fit(X_train, y_train, validation_data=(X_val, y_val_scale), epochs=50,callbacks=es_cb)
# Out:
# Epoch 1/50
# 211/211 [==============================] - 3s 6ms/step - loss: 2.4197 - mae: 1.1161 - val_loss: 0.6934 - val_mae: 0.6399
# Epoch 2/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.9818 - mae: 0.7418 - val_loss: 0.6233 - val_mae: 0.5976
# Epoch 3/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.8048 - mae: 0.6648 - val_loss: 0.5682 - val_mae: 0.5706
# Epoch 4/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.7056 - mae: 0.6086 - val_loss: 0.5584 - val_mae: 0.5731
# Epoch 5/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.6486 - mae: 0.5800 - val_loss: 0.4877 - val_mae: 0.5179
# Epoch 6/50
# 211/211 [==============================] - 1s 6ms/step - loss: 0.5924 - mae: 0.5446 - val_loss: 0.4436 - val_mae: 0.4866
# Epoch 7/50
# 211/211 [==============================] - 1s 6ms/step - loss: 0.5515 - mae: 0.5195 - val_loss: 0.4248 - val_mae: 0.4625
# Epoch 8/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.5003 - mae: 0.5004 - val_loss: 0.3854 - val_mae: 0.4482
# Epoch 9/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.4902 - mae: 0.4862 - val_loss: 0.3758 - val_mae: 0.4555
# Epoch 10/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.4506 - mae: 0.4748 - val_loss: 0.3469 - val_mae: 0.4276
# Epoch 11/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.4268 - mae: 0.4576 - val_loss: 0.3573 - val_mae: 0.4377
# Epoch 12/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.4248 - mae: 0.4569 - val_loss: 0.3356 - val_mae: 0.4144
# Epoch 13/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.3960 - mae: 0.4477 - val_loss: 0.3196 - val_mae: 0.4187
# Epoch 14/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.3905 - mae: 0.4402 - val_loss: 0.3174 - val_mae: 0.3985
# Epoch 15/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.3959 - mae: 0.4389 - val_loss: 0.3143 - val_mae: 0.4241
# Epoch 16/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.3687 - mae: 0.4255 - val_loss: 0.3144 - val_mae: 0.4210
# Epoch 17/50
# 211/211 [==============================] - 1s 6ms/step - loss: 0.3705 - mae: 0.4223 - val_loss: 0.2979 - val_mae: 0.3866
# Epoch 18/50
# 211/211 [==============================] - 1s 7ms/step - loss: 0.3503 - mae: 0.4217 - val_loss: 0.2916 - val_mae: 0.3933
# Epoch 19/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.3315 - mae: 0.4156 - val_loss: 0.3039 - val_mae: 0.4192
# Epoch 20/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.3408 - mae: 0.4147 - val_loss: 0.2876 - val_mae: 0.4018
# Epoch 21/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.3294 - mae: 0.4119 - val_loss: 0.2805 - val_mae: 0.3886
# Epoch 22/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.3178 - mae: 0.4039 - val_loss: 0.2797 - val_mae: 0.3885
# Epoch 23/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.3094 - mae: 0.4027 - val_loss: 0.2832 - val_mae: 0.3905
# Epoch 24/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.3108 - mae: 0.4018 - val_loss: 0.2847 - val_mae: 0.3876
# Epoch 25/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.3133 - mae: 0.3955 - val_loss: 0.2723 - val_mae: 0.3826
# Epoch 26/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.3131 - mae: 0.3946 - val_loss: 0.2743 - val_mae: 0.3898
# Epoch 27/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.3066 - mae: 0.3963 - val_loss: 0.2686 - val_mae: 0.3811
# Epoch 28/50
# 211/211 [==============================] - 1s 6ms/step - loss: 0.2954 - mae: 0.3938 - val_loss: 0.2674 - val_mae: 0.3785
# Epoch 29/50
# 211/211 [==============================] - 1s 6ms/step - loss: 0.2900 - mae: 0.3898 - val_loss: 0.2764 - val_mae: 0.3838
# Epoch 30/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.2945 - mae: 0.3891 - val_loss: 0.2700 - val_mae: 0.3830
# Epoch 31/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.2905 - mae: 0.3865 - val_loss: 0.2660 - val_mae: 0.3720
# Epoch 32/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.2932 - mae: 0.3851 - val_loss: 0.2697 - val_mae: 0.3765
# Epoch 33/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.2983 - mae: 0.3882 - val_loss: 0.2596 - val_mae: 0.3659
# Epoch 34/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.2853 - mae: 0.3848 - val_loss: 0.2696 - val_mae: 0.3808
# Epoch 35/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.2776 - mae: 0.3786 - val_loss: 0.2642 - val_mae: 0.3747
# Epoch 36/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.2989 - mae: 0.3828 - val_loss: 0.2615 - val_mae: 0.3804
# Epoch 37/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.2705 - mae: 0.3737 - val_loss: 0.2598 - val_mae: 0.3710
# Epoch 38/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.2613 - mae: 0.3713 - val_loss: 0.2536 - val_mae: 0.3586
# Epoch 39/50
# 211/211 [==============================] - 1s 6ms/step - loss: 0.2740 - mae: 0.3709 - val_loss: 0.2676 - val_mae: 0.3943
# Epoch 40/50
# 211/211 [==============================] - 1s 7ms/step - loss: 0.2739 - mae: 0.3731 - val_loss: 0.2567 - val_mae: 0.3751
# Epoch 41/50
# 211/211 [==============================] - 1s 6ms/step - loss: 0.2643 - mae: 0.3703 - val_loss: 0.2527 - val_mae: 0.3645
# Epoch 42/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.2570 - mae: 0.3676 - val_loss: 0.2565 - val_mae: 0.3669
# Epoch 43/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.2723 - mae: 0.3695 - val_loss: 0.2571 - val_mae: 0.3711

# %%
pyplot.title('Loss / Mean Squared Error')
pyplot.plot(history_5.history['loss'], label='train')
pyplot.plot(history_5.history['val_loss'], label='validate')
pyplot.legend()
pyplot.show()

# %% [markdown]
# * We can observe that after increasing the layers, both the curves seems to be smooth.

# %%
Y_result_scaled_5= model_5.predict(X_val)
Y_result_5 = sc.inverse_transform(Y_result_scaled_5)
print(Y_result_5)
# Out:
# 91/91 [==============================] - 0s 2ms/step
# [[ 6148.9346]
#  [12809.571 ]
#  [ 6939.896 ]
#  ...
#  [ 3976.3667]
#  [ 7480.329 ]
#  [ 9111.413 ]]

# %%
# Checking model performance on train set
print("Validation Performance\n")
model_train_perf = model_performance_regression(X_val,y_val, Y_result_5)
model_train_perf
# Out:
# Validation Performance
#           RMSE          MAE  R-squared  Adj. R-squared
# 0  2314.405872  1648.041537   0.738127        0.735744

# %%
# Lets predict on train data
Y_result_train_scaled = model_5.predict(X_train)

# As we have scaled the target variable, now after predicting we should inverse the scale and convert it to normal form
Y_result_train = sc.inverse_transform(Y_result_train_scaled)
y_train_true = sc.inverse_transform(y_train)
# print(Y_result)

# Checking model performance on train set
print("Training Performance\n")
model_train_perf = model_performance_regression(X_train, y_train_true, Y_result_train)
model_train_perf
# Out:
# 211/211 [==============================] - 0s 2ms/step
# Training Performance
#           RMSE          MAE  R-squared  Adj. R-squared
# 0  2211.808882  1586.212739   0.768357        0.767458

# %% [markdown]
# The Adjusted R-square of the model increased, and increasing the number of layers did work to improve the metrics.

# %% [markdown]
# Out of all the models built, the final Model-5 with the dropout technique gives a good Adjusted R-Square when compared to all the models. Now let's predict on the test data using Model-5.

# %% [markdown]
# #### **Test Prediction**

# %%
# Predicting on test dat
test_pred = model_5.predict(X_test)
##As we have scaled the target variable, now after predicting we should inverse the scale and should convert to normal form
test_pred = sc.inverse_transform(test_pred)
print(test_pred)
# Out:
# 34/34 [==============================] - 0s 3ms/step
# [[12121.772]
#  [ 6219.419]
#  [ 8613.243]
#  ...
#  [11612.039]
#  [ 8272.405]
#  [11329.573]]

# %%
# Checking model performance on train set
print("Testing Performance\n")
model_train_perf = model_performance_regression(X_test,y_test, test_pred)
model_train_perf
# Out:
# Testing Performance
#           RMSE          MAE  R-squared  Adj. R-squared
# 0  2814.216443  1729.985637   0.674341        0.666216

# %% [markdown]
# # Scikit-Learn Model

# %%
from sklearn.neural_network import MLPRegressor

model_skl = MLPRegressor(
    hidden_layer_sizes = (64,64),
    solver = "adam",
    activation = "relu",
    early_stopping = True,
    n_iter_no_change = 5,
    validation_fraction = 0.1,
    max_iter = 200,
    alpha = 1,
    random_state = 42
).fit(X_train, y_train)

# Lets predict on train data
Y_result_train_scaled = model_skl.predict(X_train)

# As we have scaled the target variable, now after predicting we should inverse the scale and convert it to normal form
Y_result_train = sc.inverse_transform(Y_result_train_scaled.reshape(-1, 1))
y_train_true = sc.inverse_transform(y_train)
# print(Y_result)

# Checking model performance on train set
print("Training Performance\n")
model_train_perf = model_performance_regression(X_train, y_train_true, Y_result_train)
print(model_train_perf)

# Predicting on validation dat
val_pred = model_skl.predict(X_val)
##As we have scaled the target variable, now after predicting we should inverse the scale and should convert to normal form
val_pred = sc.inverse_transform(val_pred.reshape(-1, 1))

# Checking model performance on train set
print("Validation Performance\n")
model_train_perf = model_performance_regression(X_val,y_val, val_pred)
print(model_train_perf)

# Predicting on test dat
test_pred = model_skl.predict(X_test)
##As we have scaled the target variable, now after predicting we should inverse the scale and should convert to normal form
test_pred = sc.inverse_transform(test_pred.reshape(-1, 1))

# Checking model performance on train set
print("Testing Performance\n")
model_train_perf = model_performance_regression(X_test,y_test, test_pred)
print(model_train_perf)
# Out:
# Training Performance
#
#           RMSE       MAE  R-squared  Adj. R-squared
# 0  2311.199866  1620.475   0.747071         0.74609
# Validation Performance
#
#           RMSE          MAE  R-squared  Adj. R-squared
# 0  2321.958458  1639.859946   0.736415        0.734017
# Testing Performance
#
#           RMSE          MAE  R-squared  Adj. R-squared
# 0  2751.998714  1692.323792   0.688582        0.680811

# %% [markdown]
# ### Comments
#
# - We have trained 5 different models with some changes in architecture and Optimizer.
# - Just by increasing one layer in the last model, we were able to reduce the loss.
# - Play around with your neural network model by changing the number of dense layers, learning rate, number of neurons in hidden layers. Try out different loss and activation functions and see if you can get a better Adjusted R Square.

# %% [markdown]
# ### Happy Learning !

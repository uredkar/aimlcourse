# %%
# %matplotlib inline
from matplotlib import animation, rc
from IPython.display import HTML, Image

# equivalent to rcParams['animation.html'] = 'html5'
rc('animation', html='html5')

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]  # X-axis values
y = [2, 4, 6, 8, 10]  # Y-axis values

# Calculate the absolute differences |x - y|
abs_diff = [abs(xi - yi) for xi, yi in zip(x, y)]

# Create a line chart for the absolute differences
plt.plot(x, abs_diff, marker='o', linestyle='-')  # 'o' for markers, '-' for a solid line
plt.xlabel('X-axis')
plt.ylabel('|x - y|')
plt.title('Absolute Difference Line Chart')
plt.grid(True)  # Add grid lines
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample MAE values for different experiments or models
experiments = ['Experiment 1', 'Experiment 2', 'Experiment 3', 'Experiment 4']
mae_values = [2.0, 1.5, 3.0, 2.8]  # Replace with your MAE values

# Create a line chart
plt.plot(experiments, mae_values, marker='o', linestyle='-', color='b')
plt.xlabel('Experiments')
plt.ylabel('MAE')
plt.title('Mean Absolute Error (MAE) for Different Experiments')
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the absolute value function
def absolute_value(x):
    return np.abs(x)

# Create an array of x values
x = np.linspace(-5, 5, 100)

# Calculate the absolute values
y = absolute_value(x)

# Create a plot
plt.plot(x, y, label='|x|', color='blue')
plt.xlabel('x')
plt.ylabel('|x|')
plt.title('Plot of Absolute Value Function')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a range of x values
x = np.linspace(-5, 5, 100)

# Define the squared loss function (MSE)
mse = x**2

# Create a plot
plt.plot(x, mse, label='MSE (Squared Loss)', color='blue')
plt.xlabel('x')
plt.ylabel('Loss')
plt.title('Plot of Squared Loss (Mean Squared Error)')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a range of predicted probabilities (between 0 and 1)
probs = np.linspace(0.01, 0.99, 100)

# Calculate the cross-entropy loss
cross_entropy = -np.log(probs)

# Create a plot
plt.plot(probs, cross_entropy, label='Cross-Entropy Loss', color='blue')
plt.xlabel('Predicted Probability')
plt.ylabel('Cross-Entropy Loss')
plt.title('Plot of Cross-Entropy Loss (Log Loss)')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython.display import HTML

# Sample data
X = np.array([1, 2, 3, 4, 5])  # Input features
y = np.array([2, 4, 6, 8, 10])  # Target values

# Initialize parameters
learning_rate = 0.1
initial_slope = 0
initial_intercept = 0

# Number of iterations
num_iterations = 10

# Create a figure and axis
fig, ax = plt.subplots()
ax.set_xlim(0, 6)
ax.set_ylim(0, 12)

# Create a scatter plot of the data points
sc = ax.scatter(X, y)

# Initialize a line plot for the regression line
line, = ax.plot([], [], lw=2)

# Gradient descent function
def gradient_descent(iteration):
    global initial_slope, initial_intercept
    y_pred = initial_slope * X + initial_intercept
    loss = np.mean((y_pred - y) ** 2)
    gradient_slope = np.mean(2 * (y_pred - y) * X)
    gradient_intercept = np.mean(2 * (y_pred - y))
    initial_slope -= learning_rate * gradient_slope
    initial_intercept -= learning_rate * gradient_intercept
    line.set_data(X, initial_slope * X + initial_intercept)
    return line, sc

# Create the animation
ani = FuncAnimation(fig, gradient_descent, frames=num_iterations, blit=True)

plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Gradient Descent Animation')

# Display the animation in the Jupyter Notebook
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
# ...

# %%
ani.save("gradient_descent_animation.gif", writer="pillow")

# %%
# Define the vector of input samples as x, with 20 values sampled from a uniform distribution
# between 0 and 1
x = np.random.uniform(0, 1, 20)

# Generate the target values t from x with small gaussian noise so the estimation won't
# be perfect.
# Define a function f that represents the line that generates t without noise
def f(x): return x * 2

# Create the targets t with some gaussian noise
noise_variance = 0.2  # Variance of the gaussian noise
# Gaussian noise error for each sample in x
noise = np.random.randn(x.shape[0]) * noise_variance
# Create targets t
t = f(x) + noise

# %%
# Plot the target t versus the input x
plt.plot(x, t, 'bo', label='target: t')
plt.xlabel('input: $x$', fontsize=15)
plt.ylabel('target: $t$', fontsize=15)
plt.ylim([0,2])
plt.xlim([0,1])
plt.title('Labelled data', fontsize=18)
plt.legend(loc=2)
plt.show()

# %%
#Define the neural network function y = x * w
def nn(x, w): return x * w

# Define the cost function
def cost(y, t): return ((t - y)**2).sum()

# %%
# Plot the cost vs the given weight w

# Define a vector of weights for which we want to plot the cost
ws = np.linspace(0, 4, num=100)  # weight values
cost_ws = np.vectorize(lambda w: cost(nn(x, w) , t))(ws)  # cost for each weight in ws

# Plot
plt.plot(ws, cost_ws, 'r-', label='cost')
plt.ylim([0,14])
plt.xlim([0,4])
plt.xlabel('parameter: $p$', fontsize=15)
plt.ylabel('cost: $\sum |t-y|^2$', fontsize=15)
plt.title('Cost function', fontsize=18)
plt.legend(loc=2)
plt.show()

# %%
# Animation functions
# Uses the Matplotlib animation module: http://matplotlib.org/api/animation_api.html
# More examples: http://matplotlib.org/examples/animation/

def init_fig():
    """Initialise figure"""
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,5))
    # Line vs data plot
    # Plot the fitted line agains the target line
    # Plot the target t versus the input x
    ax2.plot(x, t, 'bo', label='target: t')
    ax2.set_xlim([0, 1])
    ax2.set_ylim([0, 2])
    ax2.set_xlabel('input: $x$', fontsize=15)
    ax2.set_ylabel('target: $t$', fontsize=15)
    ax2.yaxis.set_label_position('right')
    ax2.set_title('Labelled data & model output', fontsize=18)
    line2, = ax2.plot([], [], 'k-', label='fitted line: $y=x*p$')
    ax2.legend(loc=2)
    # Cost function plot
    ax1.plot(ws, cost_ws, 'r-', label='cost')
    ax1.set_ylim([0, 14])
    ax1.set_xlim([0, 4])
    ax1.set_xlabel('parameter: $p$', fontsize=15)
    ax1.set_ylabel('cost: $\sum |t-y|^2$', fontsize=15)
    cost_text = ax1.set_title('Cost at step {}'.format(0), fontsize=18)
    line1, = ax1.plot([], [], 'k:', label='derivative at $p$')
    pc_dots, = ax1.plot([], [], 'ko')
    ax1.legend(loc=2)
    return fig, ax1, ax2, line1, line2, pc_dots, cost_text


def get_anim(fig, ax1, ax2, line1, line2, pc_dots, cost_text, weights):
    """Return animation function."""
    xs = np.linspace(0, 4, num=100)  # weight values
    #(w, dw, cost)
    def anim(i):
        """Animate step i"""
        if i == 0:
            return [line1, line2, pc_dots, cost_text]
        (w, dw, cost) = weights[i-1]
        cost_text.set_text('Cost at step {} = {:.3f}'.format(i, cost))
        ws, _, cs = zip(*weights[0:i])
        pc_dots.set_xdata(ws)
        pc_dots.set_ydata(cs)
        abline_values = [dw * (x-w) + cost for x in xs]
        line1.set_xdata(xs)
        line1.set_ydata(abline_values)
        # Plot fit
        # plot the fitted line
        line2.set_xdata([0, 1])
        line2.set_ydata([0*w, 1*w])
        ax2.legend(loc=2)
        return [line1, line2, pc_dots, cost_text]
    return anim

# %%
# define the gradient function. Remember that y = nn(x, w) = x * w
def gradient(w, x, t): 
    return 2 * x * (nn(x, w) - t)

# define the update function delta w
def delta_w(w_k, x, t, learning_rate):
    return learning_rate * gradient(w_k, x, t).sum()

# Set the initial weight parameter
w = 0.3
# Set the learning rate
learning_rate = 0.05

# Start performing the gradient descent updates, and print the weights and cost:
nb_of_iterations = 11  # number of gradient descent updates
w_cost = [(w, cost(nn(x, w), t))] # List to store the weight,costs values
weights = [(w, gradient(w, x, t).sum(), cost(nn(x, w), t))]
for i in range(nb_of_iterations):
    dw = delta_w(w, x, t, learning_rate)  # Get the delta w update
    w = w - dw  # Update the current weight parameter
    gw = gradient(w, x, t).sum()
    c = cost(nn(x, w), t)
    w_cost.append((w, c))  # Add weight,cost to list
    weights.append((w, gw, c))

# %%
# Create animation (uses ffmpeg)
fig, ax1, ax2, line1, line2, pc_dots, cost_text = init_fig()
animate = get_anim(fig, ax1, ax2, line1, line2, pc_dots, cost_text, weights)

anim = animation.FuncAnimation(fig, animate, frames=len(weights)+1, interval=800, blit=True)

# %%
anim
# Out:
# <video width="1200" height="500" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
# Create gif from animation (uses ImageMagick)
gif_path = './gradient_descent.gif'
anim.save('./gradient_descent.gif', writer='imagemagick', fps=1000/800)
Image(url=gif_path)
# Out:
# MovieWriter imagemagick unavailable; using Pillow instead.
# <img src="./gradient_descent.gif"/>

# %%
# Define the vector of input samples as x, with 20 values sampled from a uniform distribution
# between 0 and 1
x = np.random.uniform(0, 1, 400)

# Generate the target values t from x with small gaussian noise so the estimation won't
# be perfect.
# Define a function f that represents the line that generates t without noise
def f(x): return x**4 - 4*x**2

# Create the targets t with some gaussian noise
noise_variance = 0.2  # Variance of the gaussian noise
# Gaussian noise error for each sample in x
noise = np.random.randn(x.shape[0]) * noise_variance
# Create targets t
t = f(x) + noise

# %%
t.shape
# Out:
# (400,)

# %%
# Plot the target t versus the input x
plt.plot(x, t, 'bo', label='target: t')
plt.xlabel('input: $x$', fontsize=15)
plt.ylabel('target: $t$', fontsize=15)
#plt.ylim([0,2])
#plt.xlim([0,1])
plt.title('Labelled data', fontsize=18)
plt.legend(loc=2)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the range of x values
x = np.linspace(-2, 2, 400)

# Calculate the corresponding y values using the non-convex function
y = f(x) #x**4 - 4*x**2

# Create the plot
plt.plot(x, y, label='y = x^4 - 4x^2', color='blue')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Non-Convex Curve')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plot the cost vs the given weight w

# Define a vector of weights for which we want to plot the cost
ws = np.linspace(0, 4, num=100)  # weight values
cost_ws = np.vectorize(lambda w: cost(nn(x, w) , t))(ws)  # cost for each weight in ws

# Plot
plt.plot(ws, cost_ws, 'r-', label='cost')
#plt.ylim([0,14])
#plt.xlim([0,4])
plt.xlabel('parameter: $p$', fontsize=15)
plt.ylabel('cost: $\sum |t-y|^2$', fontsize=15)
plt.title('Cost function', fontsize=18)
plt.legend(loc=2)
plt.show()

# %%
# define the gradient function. Remember that y = nn(x, w) = x * w
def gradient(w, x, t): 
    return (4 * x ** 3 - 8 * x) * (nn(x, w) - t)

# define the update function delta w
def delta_w(w_k, x, t, learning_rate):
    return learning_rate * gradient(w_k, x, t).sum()

# Set the initial weight parameter
w = 0.3
# Set the learning rate
learning_rate = 0.05

# Start performing the gradient descent updates, and print the weights and cost:
nb_of_iterations = 11  # number of gradient descent updates
w_cost = [(w, cost(nn(x, w), t))] # List to store the weight,costs values
weights = [(w, gradient(w, x, t).sum(), cost(nn(x, w), t))]
for i in range(nb_of_iterations):
    dw = delta_w(w, x, t, learning_rate)  # Get the delta w update
    w = w - dw  # Update the current weight parameter
    gw = gradient(w, x, t).sum()
    c = cost(nn(x, w), t)
    w_cost.append((w, c))  # Add weight,cost to list
    weights.append((w, gw, c))

# %%
# Create animation (uses ffmpeg)
fig, ax1, ax2, line1, line2, pc_dots, cost_text = init_fig()
animate = get_anim(fig, ax1, ax2, line1, line2, pc_dots, cost_text, weights)

anim = animation.FuncAnimation(fig, animate, frames=len(weights)+1, interval=800, blit=True)

# %%
anim
# Out:
# <video width="1200" height="500" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
# Create gif from animation (uses ImageMagick)
gif_path = './gradient_descent.gif'
anim.save('./gradient_descent.gif', writer='imagemagick', fps=1000/800)
Image(url=gif_path)
# Out:
# MovieWriter imagemagick unavailable; using Pillow instead.
# <img src="./gradient_descent.gif"/>

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# Define the function and its gradient
def non_convex_function(x):
    return x**4 - 4*x**2

def gradient(x):
    return 4*x**3 - 8*x

# Gradient Descent Parameters
learning_rate = 0.1
num_iterations = 20
x_initial = -1.5  # Initial starting point

# Create a figure and axis
fig, ax = plt.subplots()
ax.set_xlim(-2, 2)
ax.set_ylim(-6, 2)

# Plot the non-convex function
x = np.linspace(-2, 2, 400)
y = non_convex_function(x)
line, = ax.plot(x, y, label='y = x^4 - 4x^2', color='blue')

# Initialize point for gradient descent
point, = ax.plot(x_initial, non_convex_function(x_initial), marker='o', markersize=6, color='red')

# Gradient descent function
def gradient_descent(iteration):
    global x_initial
    x_initial -= learning_rate * gradient(x_initial)
    point.set_data(x_initial, non_convex_function(x_initial))
    return point,

# Create the animation
ani = FuncAnimation(fig, gradient_descent, frames=num_iterations, blit=True)

plt.xlabel('x')
plt.ylabel('y')
plt.title('Gradient Descent on a Non-Convex Function')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# c:\temp\ipykernel_65924\685859926.py:34: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   point.set_data(x_initial, non_convex_function(x_initial))

# %%
ani
# Out:
# c:\temp\ipykernel_65924\685859926.py:34: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   point.set_data(x_initial, non_convex_function(x_initial))
# <video width="640" height="480" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# Define the Rosenbrock function and its gradient
def rosenbrock(x, y):
    return (1 - x)**2 + 100 * (y - x**2)**2

def gradient(x, y):
    dx = 2 * (200 * x**3 - 200 * x * y + x - 1)
    dy = 200 * (y - x**2)
    return dx, dy

# Gradient Descent Parameters
learning_rate = 0.005
num_iterations = 1000
x_initial, y_initial = -1.5, -1.5  # Initial starting point

# Create a figure and axis
fig, ax = plt.subplots()
ax.set_xlim(-2, 2)
ax.set_ylim(-2, 2)

# Create a grid of x and y values
x = np.linspace(-2, 2, 400)
y = np.linspace(-2, 2, 400)
X, Y = np.meshgrid(x, y)

# Calculate the Rosenbrock values for the grid
Z = rosenbrock(X, Y)

# Create a contour plot of the Rosenbrock function
contour = ax.contour(X, Y, Z, levels=np.logspace(-1, 3, 10), cmap='viridis')

# Initialize the point for gradient descent
point, = ax.plot(x_initial, y_initial, marker='o', markersize=6, color='red')

# Gradient descent function
def gradient_descent(iteration):
    global x_initial, y_initial
    dx, dy = gradient(x_initial, y_initial)
    x_initial -= learning_rate * dx
    y_initial -= learning_rate * dy
    point.set_data(x_initial, y_initial)
    return point,

# Create the animation
ani = FuncAnimation(fig, gradient_descent, frames=num_iterations, blit=True)

plt.xlabel('X')
plt.ylabel('Y')
plt.title('Gradient Descent on the Rosenbrock Function')
plt.grid(True)

# Display the animation
plt.show()
# Out:
# c:\temp\ipykernel_65924\3507096923.py:44: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   point.set_data(x_initial, y_initial)

# %%
ani
# Out:
# c:\temp\ipykernel_65924\3507096923.py:44: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   point.set_data(x_initial, y_initial)
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\IPython\core\formatters.py:344, in BaseFormatter.__call__(self, obj)
#     342     method = get_real_method(obj, self.print_method)
#     343     if method is not None:
# --> 344         return method()
#     345     return None
#     346 else:
#
# File ~\anaconda3\lib\site-packages\matplotlib\animation.py:1361, in Animation._repr_html_(self)
#    1359 fmt = mpl.rcParams['animation.html']
#    1360 if fmt == 'html5':
# -> 1361     return self.to_html5_video()
#    1362 elif fmt == 'jshtml':
#    1363     return self.to_jshtml()
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# Define the Ackley function and its gradient
def ackley(x, y):
    term1 = -20 * np.exp(-0.2 * np.sqrt(0.5 * (x**2 + y**2)))
    term2 = -np.exp(0.5 * (np.cos(2 * np.pi * x) + np.cos(2 * np.pi * y)))
    return term1 + term2 + np.exp(1) + 20

def gradient(x, y):
    dx = 2 * x + 2 * np.pi * np.exp(1) * np.sin(2 * np.pi * x) - 2 * np.exp(-0.2 * np.sqrt(0.5 * (x**2 + y**2))) * (x / np.sqrt(0.5 * (x**2 + y**2)))
    dy = 2 * y + 2 * np.pi * np.exp(1) * np.sin(2 * np.pi * y) - 2 * np.exp(-0.2 * np.sqrt(0.5 * (x**2 + y**2))) * (y / np.sqrt(0.5 * (x**2 + y**2)))
    return dx, dy

# Gradient Descent Parameters
learning_rate = 0.0001
num_iterations = 100
x_initial, y_initial = -1.5, -1.5  # Initial starting point

# Create a figure and axis
fig, ax = plt.subplots()
ax.set_xlim(-5, 5)
ax.set_ylim(-5, 5)

# Create a grid of x and y values
x = np.linspace(-5, 5, 400)
y = np.linspace(-5, 5, 400)
X, Y = np.meshgrid(x, y)

# Calculate the Ackley values for the grid
Z = ackley(X, Y)

# Create a contour plot of the Ackley function
contour = ax.contour(X, Y, Z, levels=np.linspace(0, 20, 20), cmap='viridis')

# Initialize the point for gradient descent
point, = ax.plot(x_initial, y_initial, marker='o', markersize=6, color='red')

# Gradient descent function
def gradient_descent(iteration):
    global x_initial, y_initial
    dx, dy = gradient(x_initial, y_initial)
    x_initial -= learning_rate * dx
    y_initial -= learning_rate * dy
    point.set_data(x_initial, y_initial)
    return point,

# Create the animation
ani = FuncAnimation(fig, gradient_descent, frames=num_iterations, blit=True)

plt.xlabel('X')
plt.ylabel('Y')
plt.title('Gradient Descent on the Ackley Function')
plt.grid(True)

# Display the animation
plt.show()
# Out:
# c:\temp\ipykernel_65924\4071129516.py:46: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   point.set_data(x_initial, y_initial)

# %%
ani
# Out:
# c:\temp\ipykernel_65924\4071129516.py:46: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   point.set_data(x_initial, y_initial)

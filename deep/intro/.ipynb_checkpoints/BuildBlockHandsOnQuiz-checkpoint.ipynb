# %% [markdown]
# ### Importing the required libraries

# %%
# Libraries to help with reading and manipulating data
import pandas as pd
import numpy as np
# libaries to help with data visualization
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
# Library to encode the variables
from sklearn.preprocessing import OneHotEncoder
 # Library to split data
from sklearn.model_selection import train_test_split  
# library to import different optimizers
from tensorflow.keras import optimizers
# Library to import different loss functions 
from tensorflow.keras import losses
from tensorflow.keras.layers import Dense
# Library to avoid the warnings 
import warnings
warnings.filterwarnings('ignore')
# importing keras library
from tensorflow import keras
# library to convert the target variables to numpy arrays
from tensorflow.keras.utils import to_categorical
# library to plot classification report
from sklearn.metrics import classification_report

# %%
data = pd.read_csv('new_preprocessed_data.csv')

# %%
data.loan_status.nunique()
# Out:
# 3

# %% [markdown]
# ### Correct Answer:  No, 3
#
# **Explanation** Since the given problem statement has three classes to predict, this will be a Multi-class classification problem. If there are two classes to predict, it will be a binary classification problem.

# %% [markdown]
# ### Q Build a Neural Network model on the dataset and Obtain accuracy by following the below steps:
#
# - Store the Independent and Dependent features in X and y
# - Use train_test split to split the data (80% for training and 20% for testing)
# - Convert the target feature into a numpy array using Keras to_categorical function
#
# Use the below parameters mentioned.
# - Number of neurons in First and second layers are 64 and 32 respectively.
# - Use ReLu as an Activation function in Hidden layers and Adam as Optimizer with 1e-3 as learning rate
# - Built the model on 50 Epochs
#
#
# - **Note** - Do not use stratify sampling and Callbacks.
#
#
# - `>`80 and `<`90
# - `>`90 and `<`95
# - `>`95
# - `<`70

# %%
#Store the Independent and Dependent features in X and y
X = data.drop('loan_status',axis=1)
Y = data[['loan_status']]

# %%
# Use train_test split to split the data (80% for training and 20% for testing)
X_train, X_test, y_train, y_test=train_test_split(X, Y, test_size=0.2, random_state=1)

# %%
# Convert the target feature into a NumPy array using Keras to_categorical function
y_train = to_categorical(y_train, 3)
y_test_cat = to_categorical(y_test, 3)

# %%
# Model Building
#Defining the model
model = keras.Sequential()
# Adding the input layer with 64 neurons with relu as an activation function with input shape 11
model.add(Dense(64, activation='relu',input_shape=(11,))) 
# Adding the first hidden layer with 32 neurons with relu as an activation function
model.add(Dense(32, activation='relu'))
# Defining the output layer with 3 neurons with softmax as an activation function
model.add(Dense(3, activation='softmax'))
# Defining the Adam Optimizers
adam = optimizers.Adam(learning_rate=1e-3)
# Compiling the model with categorical crossentropy as loss function with accuracy as metrics
model.compile(loss=losses.categorical_crossentropy, optimizer=adam, metrics=['accuracy']) 
# Fitting the model on X_train and y_train with 50 epcohs with 20% of validation split
history=model.fit(X_train, y_train, epochs=50,  validation_split=0.2,  verbose=2)
# Out:
# Epoch 1/50
# 10/10 - 1s - loss: 30.9070 - accuracy: 0.5219 - val_loss: 8.6416 - val_accuracy: 0.2375 - 916ms/epoch - 92ms/step
# Epoch 2/50
# 10/10 - 0s - loss: 7.2688 - accuracy: 0.3750 - val_loss: 10.4108 - val_accuracy: 0.5625 - 62ms/epoch - 6ms/step
# Epoch 3/50
# 10/10 - 0s - loss: 6.9147 - accuracy: 0.5063 - val_loss: 6.0000 - val_accuracy: 0.2375 - 69ms/epoch - 7ms/step
# Epoch 4/50
# 10/10 - 0s - loss: 4.5852 - accuracy: 0.4031 - val_loss: 6.5699 - val_accuracy: 0.6000 - 93ms/epoch - 9ms/step
# Epoch 5/50
# 10/10 - 0s - loss: 3.1735 - accuracy: 0.4594 - val_loss: 3.3289 - val_accuracy: 0.6000 - 113ms/epoch - 11ms/step
# Epoch 6/50
# 10/10 - 0s - loss: 2.2530 - accuracy: 0.4812 - val_loss: 1.5415 - val_accuracy: 0.3125 - 76ms/epoch - 8ms/step
# Epoch 7/50
# 10/10 - 0s - loss: 1.6638 - accuracy: 0.4062 - val_loss: 2.6900 - val_accuracy: 0.5375 - 61ms/epoch - 6ms/step
# Epoch 8/50
# 10/10 - 0s - loss: 1.9232 - accuracy: 0.4875 - val_loss: 2.2569 - val_accuracy: 0.5875 - 80ms/epoch - 8ms/step
# Epoch 9/50
# 10/10 - 0s - loss: 1.6552 - accuracy: 0.4313 - val_loss: 1.5474 - val_accuracy: 0.5250 - 81ms/epoch - 8ms/step
# Epoch 10/50
# 10/10 - 0s - loss: 1.6893 - accuracy: 0.4688 - val_loss: 1.3722 - val_accuracy: 0.5750 - 87ms/epoch - 9ms/step
# Epoch 11/50
# 10/10 - 0s - loss: 1.4615 - accuracy: 0.4406 - val_loss: 1.1240 - val_accuracy: 0.5000 - 57ms/epoch - 6ms/step
# Epoch 12/50
# 10/10 - 0s - loss: 1.3053 - accuracy: 0.5156 - val_loss: 1.6827 - val_accuracy: 0.4875 - 67ms/epoch - 7ms/step
# Epoch 13/50
# 10/10 - 0s - loss: 1.3769 - accuracy: 0.4594 - val_loss: 1.4260 - val_accuracy: 0.5750 - 59ms/epoch - 6ms/step
# Epoch 14/50
# 10/10 - 0s - loss: 1.3934 - accuracy: 0.5312 - val_loss: 1.6458 - val_accuracy: 0.2500 - 58ms/epoch - 6ms/step
# Epoch 15/50
# 10/10 - 0s - loss: 1.3334 - accuracy: 0.4688 - val_loss: 1.1978 - val_accuracy: 0.5250 - 60ms/epoch - 6ms/step
# Epoch 16/50
# 10/10 - 0s - loss: 1.3004 - accuracy: 0.4781 - val_loss: 1.4212 - val_accuracy: 0.2500 - 65ms/epoch - 7ms/step
# Epoch 17/50
# 10/10 - 0s - loss: 1.5475 - accuracy: 0.4719 - val_loss: 1.4360 - val_accuracy: 0.3125 - 60ms/epoch - 6ms/step
# Epoch 18/50
# 10/10 - 0s - loss: 1.6791 - accuracy: 0.4750 - val_loss: 1.3529 - val_accuracy: 0.3750 - 58ms/epoch - 6ms/step
# Epoch 19/50
# 10/10 - 0s - loss: 2.2751 - accuracy: 0.4719 - val_loss: 2.6785 - val_accuracy: 0.1500 - 64ms/epoch - 6ms/step
# Epoch 20/50
# 10/10 - 0s - loss: 1.8083 - accuracy: 0.4437 - val_loss: 1.1089 - val_accuracy: 0.5375 - 58ms/epoch - 6ms/step
# Epoch 21/50
# 10/10 - 0s - loss: 1.2110 - accuracy: 0.4594 - val_loss: 1.2184 - val_accuracy: 0.4875 - 57ms/epoch - 6ms/step
# Epoch 22/50
# 10/10 - 0s - loss: 1.0955 - accuracy: 0.5562 - val_loss: 1.0359 - val_accuracy: 0.4875 - 61ms/epoch - 6ms/step
# Epoch 23/50
# 10/10 - 0s - loss: 1.2257 - accuracy: 0.5063 - val_loss: 1.8407 - val_accuracy: 0.5250 - 57ms/epoch - 6ms/step
# Epoch 24/50
# 10/10 - 0s - loss: 1.4412 - accuracy: 0.5188 - val_loss: 2.0532 - val_accuracy: 0.1500 - 70ms/epoch - 7ms/step
# Epoch 25/50
# 10/10 - 0s - loss: 1.9159 - accuracy: 0.4344 - val_loss: 1.6975 - val_accuracy: 0.2375 - 78ms/epoch - 8ms/step
# Epoch 26/50
# 10/10 - 0s - loss: 1.6262 - accuracy: 0.4281 - val_loss: 1.2639 - val_accuracy: 0.6125 - 93ms/epoch - 9ms/step
# Epoch 27/50
# 10/10 - 0s - loss: 1.2003 - accuracy: 0.5094 - val_loss: 1.8513 - val_accuracy: 0.6125 - 84ms/epoch - 8ms/step
# Epoch 28/50
# 10/10 - 0s - loss: 1.4169 - accuracy: 0.4563 - val_loss: 0.9319 - val_accuracy: 0.6125 - 54ms/epoch - 5ms/step
# Epoch 29/50
# 10/10 - 0s - loss: 1.1519 - accuracy: 0.5250 - val_loss: 0.9793 - val_accuracy: 0.6125 - 66ms/epoch - 7ms/step
# Epoch 30/50
# 10/10 - 0s - loss: 1.2139 - accuracy: 0.5594 - val_loss: 1.2078 - val_accuracy: 0.3375 - 53ms/epoch - 5ms/step
# Epoch 31/50
# 10/10 - 0s - loss: 1.5322 - accuracy: 0.4906 - val_loss: 0.9173 - val_accuracy: 0.6125 - 67ms/epoch - 7ms/step
# Epoch 32/50
# 10/10 - 0s - loss: 1.9904 - accuracy: 0.4313 - val_loss: 3.0359 - val_accuracy: 0.6125 - 54ms/epoch - 5ms/step
# Epoch 33/50
# 10/10 - 0s - loss: 1.7305 - accuracy: 0.4594 - val_loss: 2.4438 - val_accuracy: 0.1500 - 87ms/epoch - 9ms/step
# Epoch 34/50
# 10/10 - 0s - loss: 1.7549 - accuracy: 0.4563 - val_loss: 0.9950 - val_accuracy: 0.6125 - 96ms/epoch - 10ms/step
# Epoch 35/50
# 10/10 - 0s - loss: 1.4540 - accuracy: 0.5469 - val_loss: 1.1806 - val_accuracy: 0.6250 - 93ms/epoch - 9ms/step
# Epoch 36/50
# 10/10 - 0s - loss: 1.2842 - accuracy: 0.5469 - val_loss: 1.7588 - val_accuracy: 0.1500 - 60ms/epoch - 6ms/step
# Epoch 37/50
# 10/10 - 0s - loss: 1.2461 - accuracy: 0.4688 - val_loss: 1.0142 - val_accuracy: 0.5125 - 71ms/epoch - 7ms/step
# Epoch 38/50
# 10/10 - 0s - loss: 1.1325 - accuracy: 0.5719 - val_loss: 1.0760 - val_accuracy: 0.4500 - 56ms/epoch - 6ms/step
# Epoch 39/50
# 10/10 - 0s - loss: 1.2728 - accuracy: 0.5188 - val_loss: 1.1770 - val_accuracy: 0.2375 - 64ms/epoch - 6ms/step
# Epoch 40/50
# 10/10 - 0s - loss: 1.2306 - accuracy: 0.4969 - val_loss: 1.7336 - val_accuracy: 0.1625 - 61ms/epoch - 6ms/step
# Epoch 41/50
# 10/10 - 0s - loss: 1.0428 - accuracy: 0.5531 - val_loss: 0.9189 - val_accuracy: 0.6125 - 69ms/epoch - 7ms/step
# Epoch 42/50
# 10/10 - 0s - loss: 1.0156 - accuracy: 0.5781 - val_loss: 1.6233 - val_accuracy: 0.6125 - 58ms/epoch - 6ms/step
# Epoch 43/50
# 10/10 - 0s - loss: 1.3183 - accuracy: 0.4906 - val_loss: 1.7497 - val_accuracy: 0.6125 - 75ms/epoch - 7ms/step
# Epoch 44/50
# 10/10 - 0s - loss: 1.6793 - accuracy: 0.4563 - val_loss: 1.5145 - val_accuracy: 0.6125 - 133ms/epoch - 13ms/step
# Epoch 45/50
# 10/10 - 0s - loss: 1.7650 - accuracy: 0.4531 - val_loss: 1.6808 - val_accuracy: 0.6125 - 117ms/epoch - 12ms/step
# Epoch 46/50
# 10/10 - 0s - loss: 1.8552 - accuracy: 0.4531 - val_loss: 1.4497 - val_accuracy: 0.2500 - 75ms/epoch - 8ms/step
# Epoch 47/50
# 10/10 - 0s - loss: 1.9114 - accuracy: 0.4531 - val_loss: 0.9774 - val_accuracy: 0.5875 - 50ms/epoch - 5ms/step
# Epoch 48/50
# 10/10 - 0s - loss: 1.3350 - accuracy: 0.4906 - val_loss: 1.0309 - val_accuracy: 0.6125 - 68ms/epoch - 7ms/step
# Epoch 49/50
# 10/10 - 0s - loss: 1.1865 - accuracy: 0.5625 - val_loss: 1.0061 - val_accuracy: 0.5000 - 58ms/epoch - 6ms/step
# Epoch 50/50
# 10/10 - 0s - loss: 1.3327 - accuracy: 0.4281 - val_loss: 2.1162 - val_accuracy: 0.6125 - 68ms/epoch - 7ms/step

# %% [markdown]
# ### Correct Answer: **<70**

# %% [markdown]
# ### Q For the above model built, find the f1 - score for the 0th class using the classification report.
#
# - 0.51 - 0.55
# - 0.71 - 0.80
# - 0.60 - 0.70
# - 0.35 - 0.50

# %%
# Predicting on Test data 
y_pred=model.predict(X_test)
# Out:
# 4/4 [==============================] - 0s 2ms/step

# %%
# Appling argmax function
y_pred_final=[]
for i in y_pred:
    y_pred_final.append(np.argmax(i))

# %%
# Classification report 
print(classification_report(y_test,y_pred_final))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.51      1.00      0.68        51
#            1       0.00      0.00      0.00        23
#            2       0.00      0.00      0.00        26
#
#     accuracy                           0.51       100
#    macro avg       0.17      0.33      0.23       100
# weighted avg       0.26      0.51      0.34       100

# %% [markdown]
# ### Correct Answer: 0.60 - 0.70

# %% [markdown]
# ### Q Build a model on the data using below hyperparameters and find the accuracy.
#
# - The number of neurons in First,second, thrid and fourth layers should be 128,64,64 and 32 respectively.
# - Use ReLu as an Activation function in Hidden layers and Adam as Optimizer with 1e-3 as learning rate
# - Built the model on 200 Epochs
#
# **Note** - Do not use stratify sampling and Callbacks.
#
# - `>`80 and `<`90
# - `>`90 and `<`95
# - `>`95
# - `<`75

# %%
# Model Building
#Defining the model
model_1 = keras.Sequential()
# Adding the input layer with 128 neurons with relu as an activation function input shape 11
model_1.add(Dense(128, activation='relu',kernel_initializer='he_uniform',input_shape=(11,))) 
# Adding the first hidden layer with 64 neurons with relu as an activation function
model_1.add(Dense(64, activation='relu',kernel_initializer='he_uniform'))
# Adding the second hidden layer with 64 neurons with relu as an activation function
model_1.add(Dense(64, activation='relu',kernel_initializer='he_uniform'))
# Adding the third hidden layer with 32 neurons with relu as an activation function
model_1.add(Dense(32, activation='relu',kernel_initializer='he_uniform'))
# Defining the output layer with 3 neurons with softmax as an activation function
model_1.add(Dense(3, activation='softmax'))
# Defining the Adam Optimizers
adam = optimizers.Adam(learning_rate=1e-3)
print(model_1.summary())
# Compiling the model with categorical crossentropy as loss function with accuracy as metrics
model_1.compile(loss=losses.categorical_crossentropy, optimizer=adam, metrics=['accuracy']) 
# Fitting the model on X_train and y_train with 200 epcohs having validation split of 20% 
history_1=model_1.fit(X_train, y_train, validation_split=0.2, epochs=200, batch_size=128, verbose=2)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_22 (Dense)            (None, 128)               1536
#
#  dense_23 (Dense)            (None, 64)                8256
#
#  dense_24 (Dense)            (None, 64)                4160
#
#  dense_25 (Dense)            (None, 32)                2080
#
#  dense_26 (Dense)            (None, 3)                 99
#
# =================================================================
# Total params: 16,131
# Trainable params: 16,131
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/200
# 3/3 - 1s - loss: 203.2203 - accuracy: 0.6250 - val_loss: 62.0869 - val_accuracy: 0.2375 - 985ms/epoch - 328ms/step
# Epoch 2/200
# 3/3 - 0s - loss: 48.6119 - accuracy: 0.3313 - val_loss: 13.1859 - val_accuracy: 0.5250 - 49ms/epoch - 16ms/step
# Epoch 3/200
# 3/3 - 0s - loss: 29.7948 - accuracy: 0.3625 - val_loss: 50.7773 - val_accuracy: 0.6125 - 43ms/epoch - 14ms/step
# Epoch 4/200
# 3/3 - 0s - loss: 43.6667 - accuracy: 0.6250 - val_loss: 38.9579 - val_accuracy: 0.6125 - 57ms/epoch - 19ms/step
# Epoch 5/200
# 3/3 - 0s - loss: 32.0111 - accuracy: 0.3719 - val_loss: 22.6056 - val_accuracy: 0.6125 - 49ms/epoch - 16ms/step
# Epoch 6/200
# 3/3 - 0s - loss: 22.9907 - accuracy: 0.6250 - val_loss: 33.5209 - val_accuracy: 0.2375 - 67ms/epoch - 22ms/step
# Epoch 7/200
# 3/3 - 0s - loss: 35.9939 - accuracy: 0.2625 - val_loss: 18.3229 - val_accuracy: 0.6125 - 47ms/epoch - 16ms/step
# Epoch 8/200
# 3/3 - 0s - loss: 16.2825 - accuracy: 0.6250 - val_loss: 29.6884 - val_accuracy: 0.1500 - 44ms/epoch - 15ms/step
# Epoch 9/200
# 3/3 - 0s - loss: 22.1971 - accuracy: 0.2094 - val_loss: 11.3615 - val_accuracy: 0.6125 - 44ms/epoch - 15ms/step
# Epoch 10/200
# 3/3 - 0s - loss: 16.6305 - accuracy: 0.6250 - val_loss: 18.3513 - val_accuracy: 0.6125 - 43ms/epoch - 14ms/step
# Epoch 11/200
# 3/3 - 0s - loss: 13.4639 - accuracy: 0.5625 - val_loss: 14.5488 - val_accuracy: 0.1500 - 39ms/epoch - 13ms/step
# Epoch 12/200
# 3/3 - 0s - loss: 9.4781 - accuracy: 0.2812 - val_loss: 5.6765 - val_accuracy: 0.6000 - 53ms/epoch - 18ms/step
# Epoch 13/200
# 3/3 - 0s - loss: 4.7970 - accuracy: 0.5688 - val_loss: 1.5871 - val_accuracy: 0.5625 - 46ms/epoch - 15ms/step
# Epoch 14/200
# 3/3 - 0s - loss: 4.7700 - accuracy: 0.3938 - val_loss: 6.8442 - val_accuracy: 0.1750 - 50ms/epoch - 17ms/step
# Epoch 15/200
# 3/3 - 0s - loss: 7.6231 - accuracy: 0.4688 - val_loss: 8.3554 - val_accuracy: 0.6125 - 46ms/epoch - 15ms/step
# Epoch 16/200
# 3/3 - 0s - loss: 6.5332 - accuracy: 0.5437 - val_loss: 26.4249 - val_accuracy: 0.1500 - 44ms/epoch - 15ms/step
# Epoch 17/200
# 3/3 - 0s - loss: 17.8488 - accuracy: 0.2812 - val_loss: 13.2791 - val_accuracy: 0.6125 - 44ms/epoch - 15ms/step
# Epoch 18/200
# 3/3 - 0s - loss: 16.6328 - accuracy: 0.5469 - val_loss: 13.8706 - val_accuracy: 0.6000 - 41ms/epoch - 14ms/step
# Epoch 19/200
# 3/3 - 0s - loss: 16.1402 - accuracy: 0.5719 - val_loss: 5.1317 - val_accuracy: 0.5625 - 46ms/epoch - 15ms/step
# Epoch 20/200
# 3/3 - 0s - loss: 6.7389 - accuracy: 0.4594 - val_loss: 10.6439 - val_accuracy: 0.1500 - 45ms/epoch - 15ms/step
# Epoch 21/200
# 3/3 - 0s - loss: 9.4992 - accuracy: 0.4781 - val_loss: 12.5012 - val_accuracy: 0.6000 - 44ms/epoch - 15ms/step
# Epoch 22/200
# 3/3 - 0s - loss: 20.6330 - accuracy: 0.2969 - val_loss: 19.1260 - val_accuracy: 0.6125 - 50ms/epoch - 17ms/step
# Epoch 23/200
# 3/3 - 0s - loss: 22.0607 - accuracy: 0.6250 - val_loss: 17.0991 - val_accuracy: 0.6125 - 44ms/epoch - 15ms/step
# Epoch 24/200
# 3/3 - 0s - loss: 13.1242 - accuracy: 0.3969 - val_loss: 12.2285 - val_accuracy: 0.6125 - 43ms/epoch - 14ms/step
# Epoch 25/200
# 3/3 - 0s - loss: 11.6920 - accuracy: 0.6250 - val_loss: 15.6961 - val_accuracy: 0.2375 - 47ms/epoch - 16ms/step
# Epoch 26/200
# 3/3 - 0s - loss: 14.6572 - accuracy: 0.2562 - val_loss: 11.2444 - val_accuracy: 0.6000 - 50ms/epoch - 17ms/step
# Epoch 27/200
# 3/3 - 0s - loss: 12.9845 - accuracy: 0.4125 - val_loss: 20.4435 - val_accuracy: 0.6125 - 50ms/epoch - 17ms/step
# Epoch 28/200
# 3/3 - 0s - loss: 18.0903 - accuracy: 0.6250 - val_loss: 14.3055 - val_accuracy: 0.6125 - 42ms/epoch - 14ms/step
# Epoch 29/200
# 3/3 - 0s - loss: 10.2509 - accuracy: 0.5250 - val_loss: 26.3211 - val_accuracy: 0.2375 - 54ms/epoch - 18ms/step
# Epoch 30/200
# 3/3 - 0s - loss: 21.8827 - accuracy: 0.1844 - val_loss: 11.9095 - val_accuracy: 0.6125 - 49ms/epoch - 16ms/step
# Epoch 31/200
# 3/3 - 0s - loss: 15.9076 - accuracy: 0.6250 - val_loss: 23.0206 - val_accuracy: 0.6125 - 46ms/epoch - 15ms/step
# Epoch 32/200
# 3/3 - 0s - loss: 17.4003 - accuracy: 0.6250 - val_loss: 16.8465 - val_accuracy: 0.1500 - 42ms/epoch - 14ms/step
# Epoch 33/200

# %% [markdown]
# ### Correct Answer: <75

# %% [markdown]
# ### Q Build a model on the data using below hyperparameters and find the precision of 0th class using the classification report.
#
# * The number of neurons in First,and second layer should be 64 and 32 respectively.
# * Use ReLu as an Activation function in Hidden layers and SGD as Optimizer with 1e-3 as learning rate
# * Built the model on 100 Epochs
#
# **Note** - Do not use stratify sampling and Callbacks.

# %% [markdown]
# - `>`80 and `<`90
# - `>`60 and `<`70
# - `>`95
# - `<`60

# %%
# Model Building
#Defining the model
model_2 = keras.Sequential()
# Adding the input layer with 64 neurons with relu as an activation function of input shape 11
model_2.add(Dense(64, activation='relu',kernel_initializer='he_uniform',input_shape=(11,)))
# Adding the first hidden layer with 32 neurons with relu as an activation function
model_2.add(Dense(32, activation='relu',kernel_initializer='he_uniform'))
# Defining the output layer with 3 neurons with softmax as an activation function
model_2.add(Dense(3, activation='softmax'))
# Deining the SGD optimizer
SGD = optimizers.SGD(learning_rate=1e-3)
# Compiling the model with categorical crossentropy as loss function with accuracy as metrics
model_2.compile(loss=losses.categorical_crossentropy, optimizer=SGD, metrics=['accuracy']) 
# Fitting the model on X_train and y_train with 200 epcohs having validation split of 20% 
history_2=model_2.fit(X_train, y_train, validation_split=0.2, epochs=100, batch_size=128, verbose=2)
# Out:
# Epoch 1/100
# 3/3 - 1s - loss: 556.5698 - accuracy: 0.3844 - val_loss: 67.1339 - val_accuracy: 0.2375 - 538ms/epoch - 179ms/step
# Epoch 2/100
# 3/3 - 0s - loss: 179.5022 - accuracy: 0.3750 - val_loss: 11.0577 - val_accuracy: 0.6125 - 48ms/epoch - 16ms/step
# Epoch 3/100
# 3/3 - 0s - loss: 19.6069 - accuracy: 0.4250 - val_loss: 3.3043 - val_accuracy: 0.1625 - 60ms/epoch - 20ms/step
# Epoch 4/100
# 3/3 - 0s - loss: 2.1795 - accuracy: 0.4750 - val_loss: 1.1299 - val_accuracy: 0.6125 - 54ms/epoch - 18ms/step
# Epoch 5/100
# 3/3 - 0s - loss: 0.9655 - accuracy: 0.6250 - val_loss: 0.9574 - val_accuracy: 0.6125 - 57ms/epoch - 19ms/step
# Epoch 6/100
# 3/3 - 0s - loss: 0.9566 - accuracy: 0.6250 - val_loss: 0.9442 - val_accuracy: 0.6125 - 57ms/epoch - 19ms/step
# Epoch 7/100
# 3/3 - 0s - loss: 0.9252 - accuracy: 0.6250 - val_loss: 0.9600 - val_accuracy: 0.6125 - 58ms/epoch - 19ms/step
# Epoch 8/100
# 3/3 - 0s - loss: 0.9273 - accuracy: 0.6250 - val_loss: 0.9497 - val_accuracy: 0.6125 - 51ms/epoch - 17ms/step
# Epoch 9/100
# 3/3 - 0s - loss: 0.9237 - accuracy: 0.6250 - val_loss: 0.9458 - val_accuracy: 0.6125 - 50ms/epoch - 17ms/step
# Epoch 10/100
# 3/3 - 0s - loss: 0.9260 - accuracy: 0.6250 - val_loss: 0.9557 - val_accuracy: 0.6125 - 62ms/epoch - 21ms/step
# Epoch 11/100
# 3/3 - 0s - loss: 0.9274 - accuracy: 0.6250 - val_loss: 0.9512 - val_accuracy: 0.6125 - 61ms/epoch - 20ms/step
# Epoch 12/100
# 3/3 - 0s - loss: 0.9303 - accuracy: 0.6250 - val_loss: 0.9465 - val_accuracy: 0.6125 - 64ms/epoch - 21ms/step
# Epoch 13/100
# 3/3 - 0s - loss: 0.9253 - accuracy: 0.6250 - val_loss: 0.9457 - val_accuracy: 0.6125 - 68ms/epoch - 23ms/step
# Epoch 14/100
# 3/3 - 0s - loss: 0.9249 - accuracy: 0.6250 - val_loss: 0.9422 - val_accuracy: 0.6125 - 68ms/epoch - 23ms/step
# Epoch 15/100
# 3/3 - 0s - loss: 0.9245 - accuracy: 0.6250 - val_loss: 0.9454 - val_accuracy: 0.6125 - 62ms/epoch - 21ms/step
# Epoch 16/100
# 3/3 - 0s - loss: 0.9241 - accuracy: 0.6250 - val_loss: 0.9494 - val_accuracy: 0.6125 - 48ms/epoch - 16ms/step
# Epoch 17/100
# 3/3 - 0s - loss: 0.9245 - accuracy: 0.6250 - val_loss: 0.9445 - val_accuracy: 0.6125 - 48ms/epoch - 16ms/step
# Epoch 18/100
# 3/3 - 0s - loss: 0.9256 - accuracy: 0.6250 - val_loss: 0.9466 - val_accuracy: 0.6125 - 63ms/epoch - 21ms/step
# Epoch 19/100
# 3/3 - 0s - loss: 0.9235 - accuracy: 0.6250 - val_loss: 0.9554 - val_accuracy: 0.6125 - 46ms/epoch - 15ms/step
# Epoch 20/100
# 3/3 - 0s - loss: 0.9248 - accuracy: 0.6250 - val_loss: 0.9477 - val_accuracy: 0.6125 - 62ms/epoch - 21ms/step
# Epoch 21/100
# 3/3 - 0s - loss: 0.9271 - accuracy: 0.6250 - val_loss: 0.9471 - val_accuracy: 0.6125 - 50ms/epoch - 17ms/step
# Epoch 22/100
# 3/3 - 0s - loss: 0.9256 - accuracy: 0.6250 - val_loss: 0.9526 - val_accuracy: 0.6125 - 83ms/epoch - 28ms/step
# Epoch 23/100
# 3/3 - 0s - loss: 0.9315 - accuracy: 0.6250 - val_loss: 0.9497 - val_accuracy: 0.6125 - 89ms/epoch - 30ms/step
# Epoch 24/100
# 3/3 - 0s - loss: 0.9244 - accuracy: 0.6250 - val_loss: 0.9488 - val_accuracy: 0.6125 - 61ms/epoch - 20ms/step
# Epoch 25/100
# 3/3 - 0s - loss: 0.9239 - accuracy: 0.6250 - val_loss: 0.9484 - val_accuracy: 0.6125 - 61ms/epoch - 20ms/step
# Epoch 26/100
# 3/3 - 0s - loss: 0.9273 - accuracy: 0.6250 - val_loss: 0.9466 - val_accuracy: 0.6125 - 63ms/epoch - 21ms/step
# Epoch 27/100
# 3/3 - 0s - loss: 0.9295 - accuracy: 0.6250 - val_loss: 0.9501 - val_accuracy: 0.6125 - 55ms/epoch - 18ms/step
# Epoch 28/100
# 3/3 - 0s - loss: 0.9251 - accuracy: 0.6250 - val_loss: 0.9507 - val_accuracy: 0.6125 - 51ms/epoch - 17ms/step
# Epoch 29/100
# 3/3 - 0s - loss: 0.9286 - accuracy: 0.6250 - val_loss: 0.9485 - val_accuracy: 0.6125 - 55ms/epoch - 18ms/step
# Epoch 30/100
# 3/3 - 0s - loss: 0.9234 - accuracy: 0.6250 - val_loss: 0.9481 - val_accuracy: 0.6125 - 56ms/epoch - 19ms/step
# Epoch 31/100
# 3/3 - 0s - loss: 0.9282 - accuracy: 0.6250 - val_loss: 0.9510 - val_accuracy: 0.6125 - 54ms/epoch - 18ms/step
# Epoch 32/100
# 3/3 - 0s - loss: 0.9261 - accuracy: 0.6250 - val_loss: 0.9490 - val_accuracy: 0.6125 - 100ms/epoch - 33ms/step
# Epoch 33/100
# 3/3 - 0s - loss: 0.9258 - accuracy: 0.6250 - val_loss: 0.9559 - val_accuracy: 0.6125 - 91ms/epoch - 30ms/step
# Epoch 34/100
# 3/3 - 0s - loss: 0.9234 - accuracy: 0.6250 - val_loss: 0.9488 - val_accuracy: 0.6125 - 56ms/epoch - 19ms/step
# Epoch 35/100
# 3/3 - 0s - loss: 0.9259 - accuracy: 0.6250 - val_loss: 0.9478 - val_accuracy: 0.6125 - 72ms/epoch - 24ms/step
# Epoch 36/100
# 3/3 - 0s - loss: 0.9243 - accuracy: 0.6250 - val_loss: 0.9486 - val_accuracy: 0.6125 - 56ms/epoch - 19ms/step
# Epoch 37/100
# 3/3 - 0s - loss: 0.9257 - accuracy: 0.6250 - val_loss: 0.9525 - val_accuracy: 0.6125 - 59ms/epoch - 20ms/step
# Epoch 38/100
# 3/3 - 0s - loss: 0.9261 - accuracy: 0.6250 - val_loss: 0.9502 - val_accuracy: 0.6125 - 54ms/epoch - 18ms/step
# Epoch 39/100
# 3/3 - 0s - loss: 0.9234 - accuracy: 0.6250 - val_loss: 0.9482 - val_accuracy: 0.6125 - 68ms/epoch - 23ms/step
# Epoch 40/100
# 3/3 - 0s - loss: 0.9255 - accuracy: 0.6250 - val_loss: 0.9520 - val_accuracy: 0.6125 - 61ms/epoch - 20ms/step
# Epoch 41/100
# 3/3 - 0s - loss: 0.9270 - accuracy: 0.6250 - val_loss: 0.9491 - val_accuracy: 0.6125 - 62ms/epoch - 21ms/step
# Epoch 42/100
# 3/3 - 0s - loss: 0.9283 - accuracy: 0.6250 - val_loss: 0.9505 - val_accuracy: 0.6125 - 68ms/epoch - 23ms/step
# Epoch 43/100
# 3/3 - 0s - loss: 0.9254 - accuracy: 0.6250 - val_loss: 0.9539 - val_accuracy: 0.6125 - 84ms/epoch - 28ms/step
# Epoch 44/100
# 3/3 - 0s - loss: 0.9268 - accuracy: 0.6250 - val_loss: 0.9663 - val_accuracy: 0.6125 - 79ms/epoch - 26ms/step
# Epoch 45/100
# 3/3 - 0s - loss: 0.9253 - accuracy: 0.6250 - val_loss: 0.9497 - val_accuracy: 0.6125 - 77ms/epoch - 26ms/step
# Epoch 46/100
# 3/3 - 0s - loss: 0.9231 - accuracy: 0.6250 - val_loss: 0.9622 - val_accuracy: 0.6125 - 61ms/epoch - 20ms/step
# Epoch 47/100
# 3/3 - 0s - loss: 0.9243 - accuracy: 0.6250 - val_loss: 0.9471 - val_accuracy: 0.6125 - 61ms/epoch - 20ms/step
# Epoch 48/100
# 3/3 - 0s - loss: 0.9296 - accuracy: 0.6250 - val_loss: 0.9492 - val_accuracy: 0.6125 - 54ms/epoch - 18ms/step
# Epoch 49/100
# 3/3 - 0s - loss: 0.9244 - accuracy: 0.6250 - val_loss: 0.9514 - val_accuracy: 0.6125 - 136ms/epoch - 45ms/step
# Epoch 50/100
# 3/3 - 0s - loss: 0.9276 - accuracy: 0.6250 - val_loss: 0.9557 - val_accuracy: 0.6125 - 90ms/epoch - 30ms/step
# Epoch 51/100
# 3/3 - 0s - loss: 0.9296 - accuracy: 0.6250 - val_loss: 0.9614 - val_accuracy: 0.6125 - 61ms/epoch - 20ms/step
# Epoch 52/100
# 3/3 - 0s - loss: 0.9284 - accuracy: 0.6250 - val_loss: 0.9479 - val_accuracy: 0.6125 - 66ms/epoch - 22ms/step
# Epoch 53/100
# 3/3 - 0s - loss: 0.9292 - accuracy: 0.6250 - val_loss: 0.9461 - val_accuracy: 0.6125 - 64ms/epoch - 21ms/step
# Epoch 54/100
# 3/3 - 0s - loss: 0.9271 - accuracy: 0.6250 - val_loss: 0.9443 - val_accuracy: 0.6125 - 57ms/epoch - 19ms/step
# Epoch 55/100
# 3/3 - 0s - loss: 0.9237 - accuracy: 0.6250 - val_loss: 0.9447 - val_accuracy: 0.6125 - 49ms/epoch - 16ms/step
# Epoch 56/100
# 3/3 - 0s - loss: 0.9257 - accuracy: 0.6250 - val_loss: 0.9677 - val_accuracy: 0.6125 - 65ms/epoch - 22ms/step
# Epoch 57/100
# 3/3 - 0s - loss: 0.9327 - accuracy: 0.6250 - val_loss: 0.9650 - val_accuracy: 0.6125 - 37ms/epoch - 12ms/step
# Epoch 58/100
# 3/3 - 0s - loss: 0.9263 - accuracy: 0.6250 - val_loss: 0.9510 - val_accuracy: 0.6125 - 42ms/epoch - 14ms/step
# Epoch 59/100
# 3/3 - 0s - loss: 0.9251 - accuracy: 0.6250 - val_loss: 0.9525 - val_accuracy: 0.6125 - 60ms/epoch - 20ms/step
# Epoch 60/100
# 3/3 - 0s - loss: 0.9243 - accuracy: 0.6250 - val_loss: 0.9600 - val_accuracy: 0.6125 - 47ms/epoch - 16ms/step
# Epoch 61/100
# 3/3 - 0s - loss: 0.9283 - accuracy: 0.6250 - val_loss: 0.9498 - val_accuracy: 0.6125 - 47ms/epoch - 16ms/step
# Epoch 62/100
# 3/3 - 0s - loss: 0.9389 - accuracy: 0.6250 - val_loss: 0.9567 - val_accuracy: 0.6125 - 38ms/epoch - 13ms/step
# Epoch 63/100
# 3/3 - 0s - loss: 0.9283 - accuracy: 0.6250 - val_loss: 0.9656 - val_accuracy: 0.6125 - 41ms/epoch - 14ms/step
# Epoch 64/100
# 3/3 - 0s - loss: 0.9350 - accuracy: 0.6250 - val_loss: 0.9526 - val_accuracy: 0.6125 - 36ms/epoch - 12ms/step
# Epoch 65/100
# 3/3 - 0s - loss: 0.9264 - accuracy: 0.6250 - val_loss: 0.9491 - val_accuracy: 0.6125 - 38ms/epoch - 13ms/step
# Epoch 66/100
# 3/3 - 0s - loss: 0.9234 - accuracy: 0.6250 - val_loss: 0.9503 - val_accuracy: 0.6125 - 53ms/epoch - 18ms/step
# Epoch 67/100
# 3/3 - 0s - loss: 0.9293 - accuracy: 0.6250 - val_loss: 0.9727 - val_accuracy: 0.6125 - 40ms/epoch - 13ms/step
# Epoch 68/100
# 3/3 - 0s - loss: 0.9293 - accuracy: 0.6250 - val_loss: 0.9506 - val_accuracy: 0.6125 - 46ms/epoch - 15ms/step
# Epoch 69/100
# 3/3 - 0s - loss: 0.9254 - accuracy: 0.6250 - val_loss: 0.9471 - val_accuracy: 0.6125 - 32ms/epoch - 11ms/step
# Epoch 70/100
# 3/3 - 0s - loss: 0.9259 - accuracy: 0.6250 - val_loss: 0.9620 - val_accuracy: 0.6125 - 46ms/epoch - 15ms/step
# Epoch 71/100
# 3/3 - 0s - loss: 0.9267 - accuracy: 0.6250 - val_loss: 0.9525 - val_accuracy: 0.6125 - 38ms/epoch - 13ms/step
# Epoch 72/100
# 3/3 - 0s - loss: 0.9247 - accuracy: 0.6250 - val_loss: 0.9501 - val_accuracy: 0.6125 - 40ms/epoch - 13ms/step
# Epoch 73/100
# 3/3 - 0s - loss: 0.9245 - accuracy: 0.6250 - val_loss: 0.9481 - val_accuracy: 0.6125 - 39ms/epoch - 13ms/step
# Epoch 74/100
# 3/3 - 0s - loss: 0.9232 - accuracy: 0.6250 - val_loss: 0.9451 - val_accuracy: 0.6125 - 77ms/epoch - 26ms/step
# Epoch 75/100
# 3/3 - 0s - loss: 0.9266 - accuracy: 0.6250 - val_loss: 0.9475 - val_accuracy: 0.6125 - 88ms/epoch - 29ms/step
# Epoch 76/100
# 3/3 - 0s - loss: 0.9271 - accuracy: 0.6250 - val_loss: 0.9478 - val_accuracy: 0.6125 - 69ms/epoch - 23ms/step
# Epoch 77/100
# 3/3 - 0s - loss: 0.9284 - accuracy: 0.6250 - val_loss: 0.9492 - val_accuracy: 0.6125 - 82ms/epoch - 27ms/step
# Epoch 78/100
# 3/3 - 0s - loss: 0.9269 - accuracy: 0.6250 - val_loss: 0.9488 - val_accuracy: 0.6125 - 44ms/epoch - 15ms/step
# Epoch 79/100
# 3/3 - 0s - loss: 0.9264 - accuracy: 0.6250 - val_loss: 0.9638 - val_accuracy: 0.6125 - 45ms/epoch - 15ms/step
# Epoch 80/100
# 3/3 - 0s - loss: 0.9296 - accuracy: 0.6250 - val_loss: 0.9498 - val_accuracy: 0.6125 - 41ms/epoch - 14ms/step
# Epoch 81/100
# 3/3 - 0s - loss: 0.9255 - accuracy: 0.6250 - val_loss: 0.9528 - val_accuracy: 0.6125 - 51ms/epoch - 17ms/step
# Epoch 82/100
# 3/3 - 0s - loss: 0.9430 - accuracy: 0.6250 - val_loss: 0.9506 - val_accuracy: 0.6125 - 49ms/epoch - 16ms/step
# Epoch 83/100
# 3/3 - 0s - loss: 0.9226 - accuracy: 0.6250 - val_loss: 0.9484 - val_accuracy: 0.6125 - 43ms/epoch - 14ms/step
# Epoch 84/100
# 3/3 - 0s - loss: 0.9245 - accuracy: 0.6250 - val_loss: 0.9616 - val_accuracy: 0.6125 - 51ms/epoch - 17ms/step
# Epoch 85/100
# 3/3 - 0s - loss: 0.9295 - accuracy: 0.6250 - val_loss: 0.9643 - val_accuracy: 0.6125 - 55ms/epoch - 18ms/step
# Epoch 86/100
# 3/3 - 0s - loss: 0.9283 - accuracy: 0.6250 - val_loss: 0.9501 - val_accuracy: 0.6125 - 43ms/epoch - 14ms/step
# Epoch 87/100
# 3/3 - 0s - loss: 0.9246 - accuracy: 0.6250 - val_loss: 0.9611 - val_accuracy: 0.6125 - 52ms/epoch - 17ms/step
# Epoch 88/100
# 3/3 - 0s - loss: 0.9449 - accuracy: 0.6250 - val_loss: 0.9536 - val_accuracy: 0.6125 - 46ms/epoch - 15ms/step
# Epoch 89/100
# 3/3 - 0s - loss: 0.9277 - accuracy: 0.6250 - val_loss: 0.9479 - val_accuracy: 0.6125 - 47ms/epoch - 16ms/step
# Epoch 90/100
# 3/3 - 0s - loss: 0.9242 - accuracy: 0.6250 - val_loss: 0.9538 - val_accuracy: 0.6125 - 46ms/epoch - 15ms/step
# Epoch 91/100
# 3/3 - 0s - loss: 0.9240 - accuracy: 0.6250 - val_loss: 0.9557 - val_accuracy: 0.6125 - 42ms/epoch - 14ms/step
# Epoch 92/100
# 3/3 - 0s - loss: 0.9245 - accuracy: 0.6250 - val_loss: 0.9470 - val_accuracy: 0.6125 - 42ms/epoch - 14ms/step
# Epoch 93/100
# 3/3 - 0s - loss: 0.9264 - accuracy: 0.6250 - val_loss: 0.9486 - val_accuracy: 0.6125 - 59ms/epoch - 20ms/step
# Epoch 94/100
# 3/3 - 0s - loss: 0.9230 - accuracy: 0.6250 - val_loss: 0.9564 - val_accuracy: 0.6125 - 48ms/epoch - 16ms/step
# Epoch 95/100
# 3/3 - 0s - loss: 0.9311 - accuracy: 0.6250 - val_loss: 0.9521 - val_accuracy: 0.6125 - 40ms/epoch - 13ms/step
# Epoch 96/100
# 3/3 - 0s - loss: 0.9287 - accuracy: 0.6250 - val_loss: 0.9552 - val_accuracy: 0.6125 - 42ms/epoch - 14ms/step
# Epoch 97/100
# 3/3 - 0s - loss: 0.9341 - accuracy: 0.6250 - val_loss: 0.9472 - val_accuracy: 0.6125 - 43ms/epoch - 14ms/step
# Epoch 98/100
# 3/3 - 0s - loss: 0.9282 - accuracy: 0.6250 - val_loss: 0.9557 - val_accuracy: 0.6125 - 68ms/epoch - 23ms/step
# Epoch 99/100
# 3/3 - 0s - loss: 0.9324 - accuracy: 0.6250 - val_loss: 0.9491 - val_accuracy: 0.6125 - 57ms/epoch - 19ms/step
# Epoch 100/100
# 3/3 - 0s - loss: 0.9249 - accuracy: 0.6250 - val_loss: 0.9533 - val_accuracy: 0.6125 - 41ms/epoch - 14ms/step

# %%
# Predicting on test data
y_pred_2=model_2.predict(X_test)
# Out:
# 4/4 [==============================] - 0s 0s/step

# %%
# Applying argmax
y_pred_final_2=[]
for i in y_pred_2:
    y_pred_final_2.append(np.argmax(i))

# %%
# Classification report
print(classification_report(y_test,y_pred_final_2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.51      1.00      0.68        51
#            1       0.00      0.00      0.00        23
#            2       0.00      0.00      0.00        26
#
#     accuracy                           0.51       100
#    macro avg       0.17      0.33      0.23       100
# weighted avg       0.26      0.51      0.34       100

# %% [markdown]
# ### Correct Answer: **<60**
